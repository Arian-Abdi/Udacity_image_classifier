# %% [markdown]
# # Developing an AI application
#
# Going forward, AI algorithms will be incorporated into more and more everyday applications. For example, you might want to include an image classifier in a smart phone app. To do this, you'd use a deep learning model trained on hundreds of thousands of images as part of the overall application architecture. A large part of software development in the future will be using these types of models as common parts of applications.
#
# In this project, you'll train an image classifier to recognize different species of flowers. You can imagine using something like this in a phone app that tells you the name of the flower your camera is looking at. In practice you'd train this classifier, then export it for use in your application. We'll be using [this dataset](http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) of 102 flower categories, you can see a few examples below.
#
#
#
# The project is broken down into multiple steps:
#
# * Load and preprocess the image dataset
# * Train the image classifier on your dataset
# * Use the trained classifier to predict image content
#
# We'll lead you through each part which you'll implement in Python.
#
# When you've completed this project, you'll have an application that can be trained on any set of labeled images. Here your network will be learning about flowers and end up as a command line application. But, what you do with your new skills depends on your imagination and effort in building a dataset. For example, imagine an app where you take a picture of a car, it tells you what the make and model is, then looks up information about it. Go build your own dataset and make something new.
#
# First up is importing the packages you'll need. It's good practice to keep all the imports at the beginning of your code. As you work through this notebook and find you need to import a package, make sure to add the import up here.

# %%
# Imports here
import numpy as np
import matplotlib.pyplot as plt
import torch
from torch import nn
from torch import tensor
from torch import optim
import torch.nn.functional as F
from torch.autograd import Variable
from torchvision import datasets, transforms
import torchvision.models as models
import argparse
from collections import OrderedDict
import json
import PIL
import seaborn as sns
from PIL import Image
import time

# %%
import os
current_directory=os.getcwd()
print(current_directory)
# Out:
# x:\Image classifier

# %% [markdown]
# ## Load the data
#
# Here you'll use `torchvision` to load the data ([documentation](http://pytorch.org/docs/0.3.0/torchvision/index.html)). The data should be included alongside this notebook, otherwise you can [download it here](https://s3.amazonaws.com/content.udacity-data.com/nd089/flower_data.tar.gz). The dataset is split into three parts, training, validation, and testing. For the training, you'll want to apply transformations such as random scaling, cropping, and flipping. This will help the network generalize leading to better performance. You'll also need to make sure the input data is resized to 224x224 pixels as required by the pre-trained networks.
#
# The validation and testing sets are used to measure the model's performance on data it hasn't seen yet. For this you don't want any scaling or rotation transformations, but you'll need to resize then crop the images to the appropriate size.
#
# The pre-trained networks you'll use were trained on the ImageNet dataset where each color channel was normalized separately. For all three sets you'll need to normalize the means and standard deviations of the images to what the network expects. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`, calculated from the ImageNet images.  These values will shift each color channel to be centered at 0 and range from -1 to 1.

# %%
data_dir = 'flowers'
train_dir = data_dir + '/train'
valid_dir = data_dir + '/valid'
test_dir = data_dir + '/test'

# %%
# TODO: Define your transforms for the training, validation, and testing sets


data_transforms = { 
    'train': transforms.Compose([
        transforms.RandomResizedCrop(size=224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485,0.456,0.406],
                             [0.229,0.224,0.225])
    ]),
    'valid': transforms.Compose([
        transforms.Resize(size=256),
        transforms.CenterCrop(size=224),
        transforms.ToTensor(),
        transforms.Normalize([0.485,0.456,0.406],
                             [0.229,0.224,0.225])
    ]),
    'test': transforms.Compose([
        transforms.Resize(size=256),
        transforms.CenterCrop(size=224),
        transforms.ToTensor(),
        transforms.Normalize([0.485,0.456,0.406],
                             [0.229,0.224,0.225])
    ])
}

# TODO: Load the datasets with ImageFolder
image_datasets = {
    'train': datasets.ImageFolder(train_dir, transform=data_transforms['train']),
    'valid': datasets.ImageFolder(valid_dir, transform=data_transforms['valid']),
    'test': datasets.ImageFolder(test_dir, transform=data_transforms['test'])
}




# TODO: Using the image datasets and the trainforms, define the dataloaders
train_loader = torch.utils.data.DataLoader(image_datasets['train'], batch_size=64, shuffle=True)
validation_loader = torch.utils.data.DataLoader(image_datasets['valid'], batch_size =64,shuffle = True)
test_loader = torch.utils.data.DataLoader(image_datasets['test'], batch_size = 64, shuffle = True)

# Size of Loaders, to be used for calculating Average Loss and Accuracy
train_Loader_size = len(train_loader)
valid_Loader_size = len(validation_loader)
test_loader_size = len(test_loader)


# Print the train, validation and test set data sizes
train_Loader_size, valid_Loader_size, test_loader_size
# Out:
# (103, 13, 13)

# %% [markdown]
# ### Label mapping
#
# You'll also need to load in a mapping from category label to category name. You can find this in the file `cat_to_name.json`. It's a JSON object which you can read in with the [`json` module](https://docs.python.org/2/library/json.html). This will give you a dictionary mapping the integer encoded categories to the actual names of the flowers.

# %%
import json

with open('cat_to_name.json', 'r') as f:
    cat_to_name = json.load(f)

# %% [markdown]
# # Building and training the classifier
#
# Now that the data is ready, it's time to build and train the classifier. As usual, you should use one of the pretrained models from `torchvision.models` to get the image features. Build and train a new feed-forward classifier using those features.
#
# We're going to leave this part up to you. Refer to [the rubric](https://review.udacity.com/#!/rubrics/1663/view) for guidance on successfully completing this section. Things you'll need to do:
#
# * Load a [pre-trained network](http://pytorch.org/docs/master/torchvision/models.html) (If you need a starting point, the VGG networks work great and are straightforward to use)
# * Define a new, untrained feed-forward network as a classifier, using ReLU activations and dropout
# * Train the classifier layers using backpropagation using the pre-trained network to get the features
# * Track the loss and accuracy on the validation set to determine the best hyperparameters
#
# We've left a cell open for you below, but use as many as you need. Our advice is to break the problem up into smaller parts you can run separately. Check that each part is doing what you expect, then move on to the next. You'll likely find that as you work through each part, you'll need to go back and modify your previous code. This is totally normal!
#
# When training make sure you're updating only the weights of the feed-forward network. You should be able to get the validation accuracy above 70% if you build everything right. Make sure to try different hyperparameters (learning rate, units in the classifier, epochs, etc) to find the best model. Save those hyperparameters to use as default values in the next part of the project.
#
# One last important tip if you're using the workspace to run your code: To avoid having your workspace disconnect during the long-running tasks in this notebook, please read in the earlier page in this lesson called Intro to
# GPU Workspaces about Keeping Your Session Active. You'll want to include code from the workspace_utils.py module.
#
# **Note for Workspace users:** If your network is over 1 GB when saved as a checkpoint, there might be issues with saving backups in your workspace. Typically this happens with wide dense layers after the convolutional layers. If your saved checkpoint is larger than 1 GB (you can open a terminal and check with `ls -lh`), you should reduce the size of your hidden layers and train again.

# %%
# TODO: Build and train your network

model = models.vgg16(pretrained=True)



#to freeze part of the convolutional part of vgg16 model and train the rest
for param in model.parameters():
    param.requires_grad = False
        



#Used OrderedDict to preserve the order in which the keys are inserted
from collections import OrderedDict

classifier = nn.Sequential(OrderedDict([
            ('inputs', nn.Linear(25088, 120)), #hidden layer 1 sets output to 120
            ('relu1', nn.ReLU()),
            ('dropout',nn.Dropout(0.5)), #could use a different droupout probability,but 0.5 usually works well
            ('hidden_layer1', nn.Linear(120, 90)), #hidden layer 2 output to 90
            ('relu2',nn.ReLU()),
            ('hidden_layer2',nn.Linear(90,70)), #hidden layer 3 output to 70
            ('relu3',nn.ReLU()),
            ('hidden_layer3',nn.Linear(70,102)),#output size = 102
            ('output', nn.LogSoftmax(dim=1))]))# For using NLLLoss()
   
model.classifier = classifier
        
#Since we will be doing the training on a GPU, we get the model ready for GPU.

# Convert model to be used on GPU
if torch.cuda.is_available():
    model.cuda()



criterion = nn.NLLLoss()
optimizer = optim.Adam(model.classifier.parameters(), lr=0.001)
# Out:
# c:\Users\arian\AppData\Local\Programs\Python\Python312\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\arian\AppData\Local\Programs\Python\Python312\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
epochs=18
for epoch in range(epochs):
    print("Epoch: {}/{}".format(epoch+1, epochs))
     
  
    # Set to training mode
    model.train()
     
    # Loss and Accuracy within the epoch
    train_loss = 0.0
    train_acc = 0.0
     
    valid_loss = 0.0
    valid_acc = 0.0
 
    for i, (inputs, labels) in enumerate(train_loader):
 
        inputs = inputs.to('cuda')
        labels = labels.to('cuda')
         
        # Clean existing gradients
        optimizer.zero_grad()
         
        # Forward pass - compute outputs on input data using the model
        outputs = model(inputs)
         
        # Compute loss
        loss = criterion(outputs, labels)
         
        # Backpropagate the gradients
        loss.backward()
         
        # Update the parameters
        optimizer.step()
         
        # Compute the total loss for the batch and add it to train_loss
        train_loss += loss.item() * inputs.size(0)
         
        # Compute the accuracy
        ret, predictions = torch.max(outputs.data, 1)
        correct_counts = predictions.eq(labels.data.view_as(predictions))
         
        # Convert correct_counts to float and then compute the mean
        acc = torch.mean(correct_counts.type(torch.FloatTensor))
         
        # Compute total accuracy in the whole batch and add to train_acc
        train_acc += acc.item() * inputs.size(0)
         
        print("Batch no: {:03d}, Loss on trainig: {:.4f}, Accuracy: {:.4f}".format(i, loss.item(), acc.item()))
# Out:
# Epoch: 1/18
# Batch no: 000, Loss on trainig: 4.6216, Accuracy: 0.0312
# Batch no: 001, Loss on trainig: 4.7152, Accuracy: 0.0000
# Batch no: 002, Loss on trainig: 4.6642, Accuracy: 0.0000
# Batch no: 003, Loss on trainig: 4.6839, Accuracy: 0.0000
# Batch no: 004, Loss on trainig: 4.6574, Accuracy: 0.0156
# Batch no: 005, Loss on trainig: 4.6532, Accuracy: 0.0469
# Batch no: 006, Loss on trainig: 4.6545, Accuracy: 0.0000
# Batch no: 007, Loss on trainig: 4.6295, Accuracy: 0.0156
# Batch no: 008, Loss on trainig: 4.6383, Accuracy: 0.0000
# Batch no: 009, Loss on trainig: 4.5795, Accuracy: 0.0312
# Batch no: 010, Loss on trainig: 4.6088, Accuracy: 0.0000
# Batch no: 011, Loss on trainig: 4.5464, Accuracy: 0.0312
# Batch no: 012, Loss on trainig: 4.5249, Accuracy: 0.0312
# Batch no: 013, Loss on trainig: 4.5665, Accuracy: 0.0000
# Batch no: 014, Loss on trainig: 4.4971, Accuracy: 0.0156
# Batch no: 015, Loss on trainig: 4.5306, Accuracy: 0.0312
# Batch no: 016, Loss on trainig: 4.5140, Accuracy: 0.0625
# Batch no: 017, Loss on trainig: 4.4838, Accuracy: 0.0312
# Batch no: 018, Loss on trainig: 4.5915, Accuracy: 0.0156
# Batch no: 019, Loss on trainig: 4.5238, Accuracy: 0.0625
# Batch no: 020, Loss on trainig: 4.4092, Accuracy: 0.0781
# Batch no: 021, Loss on trainig: 4.4057, Accuracy: 0.0625
# Batch no: 022, Loss on trainig: 4.3630, Accuracy: 0.0156
# Batch no: 023, Loss on trainig: 4.4044, Accuracy: 0.0781
# Batch no: 024, Loss on trainig: 4.4390, Accuracy: 0.0156
# Batch no: 025, Loss on trainig: 4.5940, Accuracy: 0.0781
# Batch no: 026, Loss on trainig: 4.3503, Accuracy: 0.0312
# Batch no: 027, Loss on trainig: 4.3760, Accuracy: 0.1094
# Batch no: 028, Loss on trainig: 4.4594, Accuracy: 0.0469
# Batch no: 029, Loss on trainig: 4.3309, Accuracy: 0.0469
# Batch no: 030, Loss on trainig: 4.4046, Accuracy: 0.0625
# Batch no: 031, Loss on trainig: 4.2216, Accuracy: 0.0781
# Batch no: 032, Loss on trainig: 4.5028, Accuracy: 0.0625
# Batch no: 033, Loss on trainig: 4.3562, Accuracy: 0.0938
# Batch no: 034, Loss on trainig: 4.3403, Accuracy: 0.0938
# Batch no: 035, Loss on trainig: 4.2365, Accuracy: 0.0938
# Batch no: 036, Loss on trainig: 4.3214, Accuracy: 0.0469
# Batch no: 037, Loss on trainig: 4.2094, Accuracy: 0.0781
# Batch no: 038, Loss on trainig: 4.3268, Accuracy: 0.1250
# Batch no: 039, Loss on trainig: 4.5493, Accuracy: 0.0312
# Batch no: 040, Loss on trainig: 4.2832, Accuracy: 0.1094
# Batch no: 041, Loss on trainig: 4.0699, Accuracy: 0.1562
# Batch no: 042, Loss on trainig: 4.2511, Accuracy: 0.0469
# Batch no: 043, Loss on trainig: 4.2390, Accuracy: 0.0938
# Batch no: 044, Loss on trainig: 4.2408, Accuracy: 0.0625
# Batch no: 045, Loss on trainig: 3.9960, Accuracy: 0.1562
# Batch no: 046, Loss on trainig: 4.1661, Accuracy: 0.0781
# Batch no: 047, Loss on trainig: 4.5650, Accuracy: 0.0625
# Batch no: 048, Loss on trainig: 4.2967, Accuracy: 0.0469
# Batch no: 049, Loss on trainig: 4.1478, Accuracy: 0.1406
# Batch no: 050, Loss on trainig: 4.2242, Accuracy: 0.0625
# Batch no: 051, Loss on trainig: 4.0680, Accuracy: 0.1250
# Batch no: 052, Loss on trainig: 4.0687, Accuracy: 0.0625
# Batch no: 053, Loss on trainig: 3.9940, Accuracy: 0.1562
# Batch no: 054, Loss on trainig: 4.0753, Accuracy: 0.1562
# Batch no: 055, Loss on trainig: 3.9377, Accuracy: 0.1094
# Batch no: 056, Loss on trainig: 4.0512, Accuracy: 0.1094
# Batch no: 057, Loss on trainig: 3.8941, Accuracy: 0.1250
# Batch no: 058, Loss on trainig: 3.7667, Accuracy: 0.2031
# Batch no: 059, Loss on trainig: 3.8480, Accuracy: 0.1875
# Batch no: 060, Loss on trainig: 4.1530, Accuracy: 0.0938
# Batch no: 061, Loss on trainig: 3.9982, Accuracy: 0.0938
# Batch no: 062, Loss on trainig: 3.8598, Accuracy: 0.1250
# Batch no: 063, Loss on trainig: 3.8015, Accuracy: 0.1094
# Batch no: 064, Loss on trainig: 3.8272, Accuracy: 0.1875
# Batch no: 065, Loss on trainig: 3.7231, Accuracy: 0.1719
# Batch no: 066, Loss on trainig: 3.8362, Accuracy: 0.0781
# Batch no: 067, Loss on trainig: 3.9299, Accuracy: 0.1719
# Batch no: 068, Loss on trainig: 3.7891, Accuracy: 0.0781
# Batch no: 069, Loss on trainig: 3.6287, Accuracy: 0.2031
# Batch no: 070, Loss on trainig: 3.9311, Accuracy: 0.1562
# Batch no: 071, Loss on trainig: 3.9688, Accuracy: 0.1406
# Batch no: 072, Loss on trainig: 3.7600, Accuracy: 0.2188
# Batch no: 073, Loss on trainig: 3.7562, Accuracy: 0.1719
# Batch no: 074, Loss on trainig: 3.4954, Accuracy: 0.1719
# Batch no: 075, Loss on trainig: 3.4748, Accuracy: 0.1250
# Batch no: 076, Loss on trainig: 3.6778, Accuracy: 0.2188
# Batch no: 077, Loss on trainig: 3.3881, Accuracy: 0.1562
# Batch no: 078, Loss on trainig: 3.6998, Accuracy: 0.1875
# Batch no: 079, Loss on trainig: 3.7010, Accuracy: 0.1875
# Batch no: 080, Loss on trainig: 3.8475, Accuracy: 0.1406
# Batch no: 081, Loss on trainig: 3.3424, Accuracy: 0.2188
# Batch no: 082, Loss on trainig: 3.5998, Accuracy: 0.2188
# Batch no: 083, Loss on trainig: 3.5284, Accuracy: 0.1406
# Batch no: 084, Loss on trainig: 3.7447, Accuracy: 0.0938
# Batch no: 085, Loss on trainig: 3.5918, Accuracy: 0.2188
# Batch no: 086, Loss on trainig: 3.8964, Accuracy: 0.1562
# Batch no: 087, Loss on trainig: 3.4130, Accuracy: 0.1562
# Batch no: 088, Loss on trainig: 3.5307, Accuracy: 0.1875
# Batch no: 089, Loss on trainig: 3.4997, Accuracy: 0.2344
# Batch no: 090, Loss on trainig: 3.2674, Accuracy: 0.2656
# Batch no: 091, Loss on trainig: 3.5604, Accuracy: 0.1875
# Batch no: 092, Loss on trainig: 3.5009, Accuracy: 0.2031
# Batch no: 093, Loss on trainig: 3.4090, Accuracy: 0.2188
# Batch no: 094, Loss on trainig: 3.6469, Accuracy: 0.1250
# Batch no: 095, Loss on trainig: 3.3562, Accuracy: 0.2344
# Batch no: 096, Loss on trainig: 3.2875, Accuracy: 0.2344
# Batch no: 097, Loss on trainig: 3.2592, Accuracy: 0.2656
# Batch no: 098, Loss on trainig: 3.3822, Accuracy: 0.2188
# Batch no: 099, Loss on trainig: 3.3542, Accuracy: 0.1562
# Batch no: 100, Loss on trainig: 3.5004, Accuracy: 0.2031
# Batch no: 101, Loss on trainig: 3.2796, Accuracy: 0.2344
# Batch no: 102, Loss on trainig: 3.3299, Accuracy: 0.2500
# Epoch: 2/18
# Batch no: 000, Loss on trainig: 3.4071, Accuracy: 0.1875
# Batch no: 001, Loss on trainig: 3.3010, Accuracy: 0.2188
# Batch no: 002, Loss on trainig: 3.0524, Accuracy: 0.2031
# Batch no: 003, Loss on trainig: 3.0414, Accuracy: 0.3750
# Batch no: 004, Loss on trainig: 3.4332, Accuracy: 0.2188
# Batch no: 005, Loss on trainig: 2.9677, Accuracy: 0.2969
# Batch no: 006, Loss on trainig: 3.0879, Accuracy: 0.2500
# Batch no: 007, Loss on trainig: 3.1328, Accuracy: 0.2188
# Batch no: 008, Loss on trainig: 3.2831, Accuracy: 0.2656
# Batch no: 009, Loss on trainig: 3.1928, Accuracy: 0.2656
# Batch no: 010, Loss on trainig: 3.0660, Accuracy: 0.2969
# Batch no: 011, Loss on trainig: 3.0940, Accuracy: 0.2500
# Batch no: 012, Loss on trainig: 2.7815, Accuracy: 0.3438
# Batch no: 013, Loss on trainig: 2.7533, Accuracy: 0.3750
# Batch no: 014, Loss on trainig: 3.1956, Accuracy: 0.2500
# Batch no: 015, Loss on trainig: 3.4756, Accuracy: 0.1875
# Batch no: 016, Loss on trainig: 2.5322, Accuracy: 0.3125
# Batch no: 017, Loss on trainig: 3.0631, Accuracy: 0.2656
# Batch no: 018, Loss on trainig: 3.0127, Accuracy: 0.2656
# Batch no: 019, Loss on trainig: 2.9640, Accuracy: 0.2969
# Batch no: 020, Loss on trainig: 3.1942, Accuracy: 0.2344
# Batch no: 021, Loss on trainig: 3.1400, Accuracy: 0.1719
# Batch no: 022, Loss on trainig: 3.1079, Accuracy: 0.2188
# Batch no: 023, Loss on trainig: 3.0863, Accuracy: 0.2344
# Batch no: 024, Loss on trainig: 3.0482, Accuracy: 0.2031
# Batch no: 025, Loss on trainig: 3.1735, Accuracy: 0.1562
# Batch no: 026, Loss on trainig: 2.9186, Accuracy: 0.2656
# Batch no: 027, Loss on trainig: 2.9763, Accuracy: 0.2812
# Batch no: 028, Loss on trainig: 3.0183, Accuracy: 0.1875
# Batch no: 029, Loss on trainig: 3.1206, Accuracy: 0.2656
# Batch no: 030, Loss on trainig: 2.6888, Accuracy: 0.3906
# Batch no: 031, Loss on trainig: 2.5392, Accuracy: 0.4375
# Batch no: 032, Loss on trainig: 2.6958, Accuracy: 0.3281
# Batch no: 033, Loss on trainig: 3.0592, Accuracy: 0.2188
# Batch no: 034, Loss on trainig: 3.4125, Accuracy: 0.2031
# Batch no: 035, Loss on trainig: 3.0123, Accuracy: 0.3125
# Batch no: 036, Loss on trainig: 2.8457, Accuracy: 0.3125
# Batch no: 037, Loss on trainig: 2.8899, Accuracy: 0.2656
# Batch no: 038, Loss on trainig: 2.8640, Accuracy: 0.2656
# Batch no: 039, Loss on trainig: 2.5027, Accuracy: 0.3594
# Batch no: 040, Loss on trainig: 3.0149, Accuracy: 0.2031
# Batch no: 041, Loss on trainig: 2.6854, Accuracy: 0.2969
# Batch no: 042, Loss on trainig: 2.6962, Accuracy: 0.3125
# Batch no: 043, Loss on trainig: 2.6265, Accuracy: 0.3281
# Batch no: 044, Loss on trainig: 2.7121, Accuracy: 0.2969
# Batch no: 045, Loss on trainig: 2.8236, Accuracy: 0.2812
# Batch no: 046, Loss on trainig: 2.6155, Accuracy: 0.4219
# Batch no: 047, Loss on trainig: 2.9926, Accuracy: 0.2656
# Batch no: 048, Loss on trainig: 2.9356, Accuracy: 0.2656
# Batch no: 049, Loss on trainig: 2.4659, Accuracy: 0.3750
# Batch no: 050, Loss on trainig: 2.8996, Accuracy: 0.3125
# Batch no: 051, Loss on trainig: 2.8328, Accuracy: 0.2188
# Batch no: 052, Loss on trainig: 2.9437, Accuracy: 0.2812
# Batch no: 053, Loss on trainig: 2.6704, Accuracy: 0.3281
# Batch no: 054, Loss on trainig: 2.6334, Accuracy: 0.3125
# Batch no: 055, Loss on trainig: 3.0572, Accuracy: 0.1875
# Batch no: 056, Loss on trainig: 2.6180, Accuracy: 0.3125
# Batch no: 057, Loss on trainig: 2.7524, Accuracy: 0.3281
# Batch no: 058, Loss on trainig: 2.9114, Accuracy: 0.2969
# Batch no: 059, Loss on trainig: 3.0722, Accuracy: 0.1875
# Batch no: 060, Loss on trainig: 2.4146, Accuracy: 0.3750
# Batch no: 061, Loss on trainig: 2.6357, Accuracy: 0.2969
# Batch no: 062, Loss on trainig: 2.6068, Accuracy: 0.3438
# Batch no: 063, Loss on trainig: 2.6716, Accuracy: 0.3594
# Batch no: 064, Loss on trainig: 2.4677, Accuracy: 0.3594
# Batch no: 065, Loss on trainig: 2.5430, Accuracy: 0.3125
# Batch no: 066, Loss on trainig: 2.5948, Accuracy: 0.2969
# Batch no: 067, Loss on trainig: 2.5808, Accuracy: 0.2656
# Batch no: 068, Loss on trainig: 2.6083, Accuracy: 0.4219
# Batch no: 069, Loss on trainig: 2.6494, Accuracy: 0.3438
# Batch no: 070, Loss on trainig: 2.5965, Accuracy: 0.3125
# Batch no: 071, Loss on trainig: 2.5291, Accuracy: 0.3750
# Batch no: 072, Loss on trainig: 2.3046, Accuracy: 0.4688
# Batch no: 073, Loss on trainig: 2.6956, Accuracy: 0.2812
# Batch no: 074, Loss on trainig: 3.1502, Accuracy: 0.2344
# Batch no: 075, Loss on trainig: 2.6011, Accuracy: 0.3438
# Batch no: 076, Loss on trainig: 2.2581, Accuracy: 0.3906
# Batch no: 077, Loss on trainig: 2.4206, Accuracy: 0.3750
# Batch no: 078, Loss on trainig: 2.9953, Accuracy: 0.3281
# Batch no: 079, Loss on trainig: 2.2926, Accuracy: 0.3750
# Batch no: 080, Loss on trainig: 2.0683, Accuracy: 0.4375
# Batch no: 081, Loss on trainig: 2.5787, Accuracy: 0.2812
# Batch no: 082, Loss on trainig: 2.6723, Accuracy: 0.1875
# Batch no: 083, Loss on trainig: 2.4857, Accuracy: 0.3750
# Batch no: 084, Loss on trainig: 2.3228, Accuracy: 0.4062
# Batch no: 085, Loss on trainig: 2.8867, Accuracy: 0.3125
# Batch no: 086, Loss on trainig: 2.5172, Accuracy: 0.3438
# Batch no: 087, Loss on trainig: 2.4781, Accuracy: 0.3750
# Batch no: 088, Loss on trainig: 2.6628, Accuracy: 0.3125
# Batch no: 089, Loss on trainig: 2.2957, Accuracy: 0.4062
# Batch no: 090, Loss on trainig: 2.9621, Accuracy: 0.3438
# Batch no: 091, Loss on trainig: 2.6629, Accuracy: 0.3438
# Batch no: 092, Loss on trainig: 2.3540, Accuracy: 0.3594
# Batch no: 093, Loss on trainig: 2.9013, Accuracy: 0.3281
# Batch no: 094, Loss on trainig: 2.4823, Accuracy: 0.4062
# Batch no: 095, Loss on trainig: 2.4562, Accuracy: 0.2812
# Batch no: 096, Loss on trainig: 2.8542, Accuracy: 0.2812
# Batch no: 097, Loss on trainig: 2.5135, Accuracy: 0.3125
# Batch no: 098, Loss on trainig: 2.3014, Accuracy: 0.3281
# Batch no: 099, Loss on trainig: 2.6408, Accuracy: 0.2656
# Batch no: 100, Loss on trainig: 2.4021, Accuracy: 0.3594
# Batch no: 101, Loss on trainig: 2.5886, Accuracy: 0.3125
# Batch no: 102, Loss on trainig: 2.6167, Accuracy: 0.3333
# Epoch: 3/18
# Batch no: 000, Loss on trainig: 2.3134, Accuracy: 0.3438
# Batch no: 001, Loss on trainig: 2.5297, Accuracy: 0.3750
# Batch no: 002, Loss on trainig: 2.3447, Accuracy: 0.3750
# Batch no: 003, Loss on trainig: 2.2688, Accuracy: 0.3750
# Batch no: 004, Loss on trainig: 2.3101, Accuracy: 0.2969
# Batch no: 005, Loss on trainig: 2.7175, Accuracy: 0.3281
# Batch no: 006, Loss on trainig: 2.5631, Accuracy: 0.2969
# Batch no: 007, Loss on trainig: 2.3033, Accuracy: 0.4531
# Batch no: 008, Loss on trainig: 2.7675, Accuracy: 0.3594
# Batch no: 009, Loss on trainig: 2.7242, Accuracy: 0.3750
# Batch no: 010, Loss on trainig: 2.6388, Accuracy: 0.3594
# Batch no: 011, Loss on trainig: 2.0996, Accuracy: 0.4219
# Batch no: 012, Loss on trainig: 2.6652, Accuracy: 0.3906
# Batch no: 013, Loss on trainig: 2.5909, Accuracy: 0.4062
# Batch no: 014, Loss on trainig: 2.4404, Accuracy: 0.3281
# Batch no: 015, Loss on trainig: 2.3065, Accuracy: 0.3281
# Batch no: 016, Loss on trainig: 2.5067, Accuracy: 0.3438
# Batch no: 017, Loss on trainig: 2.6094, Accuracy: 0.2812
# Batch no: 018, Loss on trainig: 2.1422, Accuracy: 0.3906
# Batch no: 019, Loss on trainig: 2.6333, Accuracy: 0.2969
# Batch no: 020, Loss on trainig: 2.0472, Accuracy: 0.4688
# Batch no: 021, Loss on trainig: 2.2608, Accuracy: 0.3438
# Batch no: 022, Loss on trainig: 2.0649, Accuracy: 0.4375
# Batch no: 023, Loss on trainig: 2.2994, Accuracy: 0.3906
# Batch no: 024, Loss on trainig: 2.5155, Accuracy: 0.3281
# Batch no: 025, Loss on trainig: 2.0400, Accuracy: 0.4844
# Batch no: 026, Loss on trainig: 2.3985, Accuracy: 0.3281
# Batch no: 027, Loss on trainig: 2.4061, Accuracy: 0.3125
# Batch no: 028, Loss on trainig: 2.3008, Accuracy: 0.3750
# Batch no: 029, Loss on trainig: 2.3005, Accuracy: 0.3594
# Batch no: 030, Loss on trainig: 2.1593, Accuracy: 0.4688
# Batch no: 031, Loss on trainig: 2.2038, Accuracy: 0.4375
# Batch no: 032, Loss on trainig: 2.2819, Accuracy: 0.4219
# Batch no: 033, Loss on trainig: 2.3293, Accuracy: 0.3906
# Batch no: 034, Loss on trainig: 2.4626, Accuracy: 0.3438
# Batch no: 035, Loss on trainig: 2.2997, Accuracy: 0.3594
# Batch no: 036, Loss on trainig: 2.3160, Accuracy: 0.3750
# Batch no: 037, Loss on trainig: 2.3460, Accuracy: 0.3750
# Batch no: 038, Loss on trainig: 2.1290, Accuracy: 0.4219
# Batch no: 039, Loss on trainig: 2.1331, Accuracy: 0.4375
# Batch no: 040, Loss on trainig: 2.0264, Accuracy: 0.3906
# Batch no: 041, Loss on trainig: 1.9811, Accuracy: 0.5000
# Batch no: 042, Loss on trainig: 2.2598, Accuracy: 0.3906
# Batch no: 043, Loss on trainig: 2.2474, Accuracy: 0.3750
# Batch no: 044, Loss on trainig: 2.6315, Accuracy: 0.3125
# Batch no: 045, Loss on trainig: 2.4210, Accuracy: 0.3125
# Batch no: 046, Loss on trainig: 2.2593, Accuracy: 0.3594
# Batch no: 047, Loss on trainig: 2.5018, Accuracy: 0.3750
# Batch no: 048, Loss on trainig: 2.5352, Accuracy: 0.3594
# Batch no: 049, Loss on trainig: 1.9463, Accuracy: 0.4531
# Batch no: 050, Loss on trainig: 2.8670, Accuracy: 0.3125
# Batch no: 051, Loss on trainig: 2.2124, Accuracy: 0.4688
# Batch no: 052, Loss on trainig: 2.0034, Accuracy: 0.4531
# Batch no: 053, Loss on trainig: 2.3488, Accuracy: 0.3438
# Batch no: 054, Loss on trainig: 2.1403, Accuracy: 0.5156
# Batch no: 055, Loss on trainig: 2.3158, Accuracy: 0.3281
# Batch no: 056, Loss on trainig: 2.4656, Accuracy: 0.3594
# Batch no: 057, Loss on trainig: 2.2949, Accuracy: 0.4219
# Batch no: 058, Loss on trainig: 2.2281, Accuracy: 0.3906
# Batch no: 059, Loss on trainig: 2.2637, Accuracy: 0.4062
# Batch no: 060, Loss on trainig: 2.5204, Accuracy: 0.2812
# Batch no: 061, Loss on trainig: 2.3887, Accuracy: 0.3750
# Batch no: 062, Loss on trainig: 2.4926, Accuracy: 0.3594
# Batch no: 063, Loss on trainig: 2.3259, Accuracy: 0.3750
# Batch no: 064, Loss on trainig: 2.3541, Accuracy: 0.3906
# Batch no: 065, Loss on trainig: 2.2118, Accuracy: 0.4062
# Batch no: 066, Loss on trainig: 2.2379, Accuracy: 0.4219
# Batch no: 067, Loss on trainig: 2.3698, Accuracy: 0.4219
# Batch no: 068, Loss on trainig: 2.0797, Accuracy: 0.4219
# Batch no: 069, Loss on trainig: 2.4073, Accuracy: 0.4219
# Batch no: 070, Loss on trainig: 2.2550, Accuracy: 0.4688
# Batch no: 071, Loss on trainig: 2.0842, Accuracy: 0.4219
# Batch no: 072, Loss on trainig: 2.3162, Accuracy: 0.3750
# Batch no: 073, Loss on trainig: 2.2484, Accuracy: 0.4375
# Batch no: 074, Loss on trainig: 1.9878, Accuracy: 0.4219
# Batch no: 075, Loss on trainig: 2.3392, Accuracy: 0.3750
# Batch no: 076, Loss on trainig: 2.4444, Accuracy: 0.3125
# Batch no: 077, Loss on trainig: 2.1247, Accuracy: 0.4062
# Batch no: 078, Loss on trainig: 2.1880, Accuracy: 0.4062
# Batch no: 079, Loss on trainig: 2.2437, Accuracy: 0.3906
# Batch no: 080, Loss on trainig: 2.6225, Accuracy: 0.2969
# Batch no: 081, Loss on trainig: 2.1571, Accuracy: 0.4219
# Batch no: 082, Loss on trainig: 2.5959, Accuracy: 0.2969
# Batch no: 083, Loss on trainig: 2.0888, Accuracy: 0.4375
# Batch no: 084, Loss on trainig: 1.9604, Accuracy: 0.4375
# Batch no: 085, Loss on trainig: 2.1987, Accuracy: 0.4062
# Batch no: 086, Loss on trainig: 2.0367, Accuracy: 0.4219
# Batch no: 087, Loss on trainig: 2.0972, Accuracy: 0.4062
# Batch no: 088, Loss on trainig: 1.5990, Accuracy: 0.6094
# Batch no: 089, Loss on trainig: 2.2736, Accuracy: 0.3750
# Batch no: 090, Loss on trainig: 2.2161, Accuracy: 0.3281
# Batch no: 091, Loss on trainig: 2.5548, Accuracy: 0.3125
# Batch no: 092, Loss on trainig: 2.1762, Accuracy: 0.3906
# Batch no: 093, Loss on trainig: 2.2219, Accuracy: 0.3750
# Batch no: 094, Loss on trainig: 2.7659, Accuracy: 0.2812
# Batch no: 095, Loss on trainig: 2.3139, Accuracy: 0.3594
# Batch no: 096, Loss on trainig: 2.1159, Accuracy: 0.3906
# Batch no: 097, Loss on trainig: 2.3022, Accuracy: 0.3750
# Batch no: 098, Loss on trainig: 2.4450, Accuracy: 0.3594
# Batch no: 099, Loss on trainig: 2.4359, Accuracy: 0.3125
# Batch no: 100, Loss on trainig: 2.2519, Accuracy: 0.3906
# Batch no: 101, Loss on trainig: 1.8923, Accuracy: 0.5000
# Batch no: 102, Loss on trainig: 2.3097, Accuracy: 0.4167
# Epoch: 4/18
# Batch no: 000, Loss on trainig: 2.1459, Accuracy: 0.4375
# Batch no: 001, Loss on trainig: 2.1807, Accuracy: 0.4062
# Batch no: 002, Loss on trainig: 2.0319, Accuracy: 0.4531
# Batch no: 003, Loss on trainig: 2.2492, Accuracy: 0.4219
# Batch no: 004, Loss on trainig: 2.1586, Accuracy: 0.3906
# Batch no: 005, Loss on trainig: 1.9499, Accuracy: 0.4688
# Batch no: 006, Loss on trainig: 2.6102, Accuracy: 0.3125
# Batch no: 007, Loss on trainig: 2.0132, Accuracy: 0.3750
# Batch no: 008, Loss on trainig: 1.8220, Accuracy: 0.5312
# Batch no: 009, Loss on trainig: 2.1298, Accuracy: 0.4219
# Batch no: 010, Loss on trainig: 1.8196, Accuracy: 0.5156
# Batch no: 011, Loss on trainig: 1.6814, Accuracy: 0.5625
# Batch no: 012, Loss on trainig: 2.3125, Accuracy: 0.4688
# Batch no: 013, Loss on trainig: 2.5492, Accuracy: 0.3438
# Batch no: 014, Loss on trainig: 1.7175, Accuracy: 0.5781
# Batch no: 015, Loss on trainig: 2.1629, Accuracy: 0.3750
# Batch no: 016, Loss on trainig: 1.9956, Accuracy: 0.4531
# Batch no: 017, Loss on trainig: 2.1955, Accuracy: 0.3906
# Batch no: 018, Loss on trainig: 1.8057, Accuracy: 0.5312
# Batch no: 019, Loss on trainig: 2.1116, Accuracy: 0.2969
# Batch no: 020, Loss on trainig: 2.4873, Accuracy: 0.3906
# Batch no: 021, Loss on trainig: 1.8627, Accuracy: 0.4844
# Batch no: 022, Loss on trainig: 1.9075, Accuracy: 0.5625
# Batch no: 023, Loss on trainig: 2.3476, Accuracy: 0.3281
# Batch no: 024, Loss on trainig: 1.9909, Accuracy: 0.4844
# Batch no: 025, Loss on trainig: 2.2602, Accuracy: 0.3438
# Batch no: 026, Loss on trainig: 2.3854, Accuracy: 0.4375
# Batch no: 027, Loss on trainig: 2.0420, Accuracy: 0.4219
# Batch no: 028, Loss on trainig: 2.1562, Accuracy: 0.4062
# Batch no: 029, Loss on trainig: 2.1843, Accuracy: 0.4375
# Batch no: 030, Loss on trainig: 2.1844, Accuracy: 0.3906
# Batch no: 031, Loss on trainig: 2.0253, Accuracy: 0.4688
# Batch no: 032, Loss on trainig: 2.1158, Accuracy: 0.5156
# Batch no: 033, Loss on trainig: 2.1743, Accuracy: 0.3906
# Batch no: 034, Loss on trainig: 2.1568, Accuracy: 0.4062
# Batch no: 035, Loss on trainig: 2.0389, Accuracy: 0.4062
# Batch no: 036, Loss on trainig: 2.0131, Accuracy: 0.4219
# Batch no: 037, Loss on trainig: 2.0547, Accuracy: 0.4375
# Batch no: 038, Loss on trainig: 1.7950, Accuracy: 0.5312
# Batch no: 039, Loss on trainig: 1.8610, Accuracy: 0.5000
# Batch no: 040, Loss on trainig: 2.1356, Accuracy: 0.4844
# Batch no: 041, Loss on trainig: 2.2178, Accuracy: 0.3750
# Batch no: 042, Loss on trainig: 2.2456, Accuracy: 0.4062
# Batch no: 043, Loss on trainig: 2.0289, Accuracy: 0.4062
# Batch no: 044, Loss on trainig: 2.1605, Accuracy: 0.3906
# Batch no: 045, Loss on trainig: 2.1737, Accuracy: 0.4062
# Batch no: 046, Loss on trainig: 2.1698, Accuracy: 0.3281
# Batch no: 047, Loss on trainig: 1.7056, Accuracy: 0.4844
# Batch no: 048, Loss on trainig: 2.3656, Accuracy: 0.4688
# Batch no: 049, Loss on trainig: 2.2707, Accuracy: 0.3906
# Batch no: 050, Loss on trainig: 1.9195, Accuracy: 0.4531
# Batch no: 051, Loss on trainig: 2.0576, Accuracy: 0.5156
# Batch no: 052, Loss on trainig: 2.1888, Accuracy: 0.3594
# Batch no: 053, Loss on trainig: 2.1227, Accuracy: 0.4219
# Batch no: 054, Loss on trainig: 2.4256, Accuracy: 0.3438
# Batch no: 055, Loss on trainig: 2.1276, Accuracy: 0.4844
# Batch no: 056, Loss on trainig: 2.3702, Accuracy: 0.4375
# Batch no: 057, Loss on trainig: 2.0261, Accuracy: 0.3438
# Batch no: 058, Loss on trainig: 2.1305, Accuracy: 0.4844
# Batch no: 059, Loss on trainig: 2.4347, Accuracy: 0.3438
# Batch no: 060, Loss on trainig: 1.7554, Accuracy: 0.5000
# Batch no: 061, Loss on trainig: 1.8332, Accuracy: 0.5469
# Batch no: 062, Loss on trainig: 2.0665, Accuracy: 0.3906
# Batch no: 063, Loss on trainig: 1.9621, Accuracy: 0.4531
# Batch no: 064, Loss on trainig: 2.5402, Accuracy: 0.2812
# Batch no: 065, Loss on trainig: 2.2681, Accuracy: 0.4219
# Batch no: 066, Loss on trainig: 1.8773, Accuracy: 0.4375
# Batch no: 067, Loss on trainig: 1.6213, Accuracy: 0.5312
# Batch no: 068, Loss on trainig: 1.8147, Accuracy: 0.5312
# Batch no: 069, Loss on trainig: 2.0736, Accuracy: 0.4531
# Batch no: 070, Loss on trainig: 1.9505, Accuracy: 0.4844
# Batch no: 071, Loss on trainig: 2.2038, Accuracy: 0.4219
# Batch no: 072, Loss on trainig: 2.2838, Accuracy: 0.4375
# Batch no: 073, Loss on trainig: 2.5857, Accuracy: 0.3750
# Batch no: 074, Loss on trainig: 2.2436, Accuracy: 0.3750
# Batch no: 075, Loss on trainig: 1.8756, Accuracy: 0.4844
# Batch no: 076, Loss on trainig: 2.0700, Accuracy: 0.3906
# Batch no: 077, Loss on trainig: 2.6557, Accuracy: 0.3750
# Batch no: 078, Loss on trainig: 2.1893, Accuracy: 0.3750
# Batch no: 079, Loss on trainig: 2.1147, Accuracy: 0.4531
# Batch no: 080, Loss on trainig: 1.9030, Accuracy: 0.4531
# Batch no: 081, Loss on trainig: 2.2370, Accuracy: 0.4219
# Batch no: 082, Loss on trainig: 2.2179, Accuracy: 0.3906
# Batch no: 083, Loss on trainig: 2.1231, Accuracy: 0.3750
# Batch no: 084, Loss on trainig: 1.8620, Accuracy: 0.5156
# Batch no: 085, Loss on trainig: 2.4554, Accuracy: 0.3438
# Batch no: 086, Loss on trainig: 1.6573, Accuracy: 0.5000
# Batch no: 087, Loss on trainig: 2.1693, Accuracy: 0.3906
# Batch no: 088, Loss on trainig: 2.1369, Accuracy: 0.4375
# Batch no: 089, Loss on trainig: 2.1198, Accuracy: 0.3750
# Batch no: 090, Loss on trainig: 1.8820, Accuracy: 0.5625
# Batch no: 091, Loss on trainig: 2.0436, Accuracy: 0.3594
# Batch no: 092, Loss on trainig: 1.6046, Accuracy: 0.5312
# Batch no: 093, Loss on trainig: 2.3128, Accuracy: 0.3750
# Batch no: 094, Loss on trainig: 1.9711, Accuracy: 0.4062
# Batch no: 095, Loss on trainig: 2.0792, Accuracy: 0.4219
# Batch no: 096, Loss on trainig: 2.2309, Accuracy: 0.4375
# Batch no: 097, Loss on trainig: 1.7529, Accuracy: 0.4531
# Batch no: 098, Loss on trainig: 1.4753, Accuracy: 0.5156
# Batch no: 099, Loss on trainig: 1.9204, Accuracy: 0.4688
# Batch no: 100, Loss on trainig: 1.9174, Accuracy: 0.4844
# Batch no: 101, Loss on trainig: 2.0889, Accuracy: 0.4531
# Batch no: 102, Loss on trainig: 2.3872, Accuracy: 0.3750
# Epoch: 5/18
# Batch no: 000, Loss on trainig: 2.1778, Accuracy: 0.4531
# Batch no: 001, Loss on trainig: 1.6286, Accuracy: 0.5781
# Batch no: 002, Loss on trainig: 2.2040, Accuracy: 0.3906
# Batch no: 003, Loss on trainig: 1.9704, Accuracy: 0.4531
# Batch no: 004, Loss on trainig: 1.7650, Accuracy: 0.4844
# Batch no: 005, Loss on trainig: 1.6565, Accuracy: 0.5312
# Batch no: 006, Loss on trainig: 2.2523, Accuracy: 0.3594
# Batch no: 007, Loss on trainig: 2.2271, Accuracy: 0.4062
# Batch no: 008, Loss on trainig: 1.9167, Accuracy: 0.5000
# Batch no: 009, Loss on trainig: 1.5008, Accuracy: 0.4844
# Batch no: 010, Loss on trainig: 1.9535, Accuracy: 0.4844
# Batch no: 011, Loss on trainig: 1.8766, Accuracy: 0.4844
# Batch no: 012, Loss on trainig: 1.8845, Accuracy: 0.5000
# Batch no: 013, Loss on trainig: 1.5312, Accuracy: 0.5312
# Batch no: 014, Loss on trainig: 2.1467, Accuracy: 0.4688
# Batch no: 015, Loss on trainig: 1.8598, Accuracy: 0.4844
# Batch no: 016, Loss on trainig: 1.8314, Accuracy: 0.4844
# Batch no: 017, Loss on trainig: 1.9363, Accuracy: 0.4219
# Batch no: 018, Loss on trainig: 1.6287, Accuracy: 0.4844
# Batch no: 019, Loss on trainig: 1.9340, Accuracy: 0.4375
# Batch no: 020, Loss on trainig: 1.8216, Accuracy: 0.4531
# Batch no: 021, Loss on trainig: 1.8516, Accuracy: 0.4062
# Batch no: 022, Loss on trainig: 1.8597, Accuracy: 0.5000
# Batch no: 023, Loss on trainig: 1.5841, Accuracy: 0.4531
# Batch no: 024, Loss on trainig: 1.9806, Accuracy: 0.5156
# Batch no: 025, Loss on trainig: 2.1697, Accuracy: 0.4062
# Batch no: 026, Loss on trainig: 2.0935, Accuracy: 0.4219
# Batch no: 027, Loss on trainig: 1.9622, Accuracy: 0.4219
# Batch no: 028, Loss on trainig: 1.8203, Accuracy: 0.4844
# Batch no: 029, Loss on trainig: 1.9763, Accuracy: 0.4375
# Batch no: 030, Loss on trainig: 2.0180, Accuracy: 0.4688
# Batch no: 031, Loss on trainig: 1.9084, Accuracy: 0.4219
# Batch no: 032, Loss on trainig: 1.9846, Accuracy: 0.4375
# Batch no: 033, Loss on trainig: 1.9798, Accuracy: 0.4844
# Batch no: 034, Loss on trainig: 2.4037, Accuracy: 0.3750
# Batch no: 035, Loss on trainig: 2.1322, Accuracy: 0.4531
# Batch no: 036, Loss on trainig: 2.2381, Accuracy: 0.5000
# Batch no: 037, Loss on trainig: 1.8659, Accuracy: 0.5000
# Batch no: 038, Loss on trainig: 2.2255, Accuracy: 0.4688
# Batch no: 039, Loss on trainig: 1.7728, Accuracy: 0.5156
# Batch no: 040, Loss on trainig: 1.6424, Accuracy: 0.4844
# Batch no: 041, Loss on trainig: 2.0970, Accuracy: 0.4375
# Batch no: 042, Loss on trainig: 2.0081, Accuracy: 0.4844
# Batch no: 043, Loss on trainig: 1.8867, Accuracy: 0.4844
# Batch no: 044, Loss on trainig: 2.1566, Accuracy: 0.3750
# Batch no: 045, Loss on trainig: 1.7572, Accuracy: 0.5000
# Batch no: 046, Loss on trainig: 2.3517, Accuracy: 0.4062
# Batch no: 047, Loss on trainig: 1.9221, Accuracy: 0.4531
# Batch no: 048, Loss on trainig: 1.6505, Accuracy: 0.5156
# Batch no: 049, Loss on trainig: 1.7421, Accuracy: 0.4844
# Batch no: 050, Loss on trainig: 2.1419, Accuracy: 0.3906
# Batch no: 051, Loss on trainig: 1.6045, Accuracy: 0.5625
# Batch no: 052, Loss on trainig: 2.4782, Accuracy: 0.3906
# Batch no: 053, Loss on trainig: 1.7788, Accuracy: 0.5312
# Batch no: 054, Loss on trainig: 1.8696, Accuracy: 0.5625
# Batch no: 055, Loss on trainig: 1.9639, Accuracy: 0.4531
# Batch no: 056, Loss on trainig: 1.6719, Accuracy: 0.5625
# Batch no: 057, Loss on trainig: 1.7552, Accuracy: 0.5469
# Batch no: 058, Loss on trainig: 2.1155, Accuracy: 0.5000
# Batch no: 059, Loss on trainig: 1.7677, Accuracy: 0.4688
# Batch no: 060, Loss on trainig: 1.6625, Accuracy: 0.5156
# Batch no: 061, Loss on trainig: 2.0764, Accuracy: 0.5312
# Batch no: 062, Loss on trainig: 1.8612, Accuracy: 0.5469
# Batch no: 063, Loss on trainig: 1.8594, Accuracy: 0.4688
# Batch no: 064, Loss on trainig: 1.7972, Accuracy: 0.5156
# Batch no: 065, Loss on trainig: 1.8973, Accuracy: 0.5781
# Batch no: 066, Loss on trainig: 1.7454, Accuracy: 0.5312
# Batch no: 067, Loss on trainig: 1.7894, Accuracy: 0.4844
# Batch no: 068, Loss on trainig: 2.0760, Accuracy: 0.4219
# Batch no: 069, Loss on trainig: 1.7047, Accuracy: 0.4844
# Batch no: 070, Loss on trainig: 1.7347, Accuracy: 0.5469
# Batch no: 071, Loss on trainig: 1.9851, Accuracy: 0.5312
# Batch no: 072, Loss on trainig: 1.4439, Accuracy: 0.5469
# Batch no: 073, Loss on trainig: 1.8580, Accuracy: 0.5781
# Batch no: 074, Loss on trainig: 2.3726, Accuracy: 0.3906
# Batch no: 075, Loss on trainig: 1.8502, Accuracy: 0.5000
# Batch no: 076, Loss on trainig: 1.9438, Accuracy: 0.5000
# Batch no: 077, Loss on trainig: 1.9475, Accuracy: 0.4688
# Batch no: 078, Loss on trainig: 1.7882, Accuracy: 0.5156
# Batch no: 079, Loss on trainig: 2.0473, Accuracy: 0.4688
# Batch no: 080, Loss on trainig: 1.9571, Accuracy: 0.4062
# Batch no: 081, Loss on trainig: 2.0946, Accuracy: 0.4375
# Batch no: 082, Loss on trainig: 2.0285, Accuracy: 0.4375
# Batch no: 083, Loss on trainig: 1.8379, Accuracy: 0.4844
# Batch no: 084, Loss on trainig: 2.0107, Accuracy: 0.4531
# Batch no: 085, Loss on trainig: 1.8143, Accuracy: 0.4844
# Batch no: 086, Loss on trainig: 1.9208, Accuracy: 0.5000
# Batch no: 087, Loss on trainig: 1.9135, Accuracy: 0.5625
# Batch no: 088, Loss on trainig: 1.9889, Accuracy: 0.4375
# Batch no: 089, Loss on trainig: 1.8130, Accuracy: 0.4844
# Batch no: 090, Loss on trainig: 2.0552, Accuracy: 0.5000
# Batch no: 091, Loss on trainig: 1.8083, Accuracy: 0.5312
# Batch no: 092, Loss on trainig: 1.6120, Accuracy: 0.4844
# Batch no: 093, Loss on trainig: 1.8515, Accuracy: 0.5000
# Batch no: 094, Loss on trainig: 1.9865, Accuracy: 0.4219
# Batch no: 095, Loss on trainig: 2.2869, Accuracy: 0.4531
# Batch no: 096, Loss on trainig: 2.0462, Accuracy: 0.4688
# Batch no: 097, Loss on trainig: 2.0078, Accuracy: 0.4531
# Batch no: 098, Loss on trainig: 1.9225, Accuracy: 0.4531
# Batch no: 099, Loss on trainig: 1.7470, Accuracy: 0.5469
# Batch no: 100, Loss on trainig: 1.7498, Accuracy: 0.5000
# Batch no: 101, Loss on trainig: 2.2040, Accuracy: 0.4062
# Batch no: 102, Loss on trainig: 2.0091, Accuracy: 0.4583
# Epoch: 6/18
# Batch no: 000, Loss on trainig: 1.7801, Accuracy: 0.4844
# Batch no: 001, Loss on trainig: 2.1647, Accuracy: 0.3438
# Batch no: 002, Loss on trainig: 2.0572, Accuracy: 0.4688
# Batch no: 003, Loss on trainig: 1.6421, Accuracy: 0.5156
# Batch no: 004, Loss on trainig: 1.8038, Accuracy: 0.5625
# Batch no: 005, Loss on trainig: 1.9843, Accuracy: 0.4219
# Batch no: 006, Loss on trainig: 1.9255, Accuracy: 0.4688
# Batch no: 007, Loss on trainig: 1.9987, Accuracy: 0.5000
# Batch no: 008, Loss on trainig: 1.8813, Accuracy: 0.5469
# Batch no: 009, Loss on trainig: 1.7760, Accuracy: 0.5781
# Batch no: 010, Loss on trainig: 2.2171, Accuracy: 0.3906
# Batch no: 011, Loss on trainig: 1.5545, Accuracy: 0.5312
# Batch no: 012, Loss on trainig: 1.7229, Accuracy: 0.5156
# Batch no: 013, Loss on trainig: 1.8875, Accuracy: 0.5000
# Batch no: 014, Loss on trainig: 1.8897, Accuracy: 0.4375
# Batch no: 015, Loss on trainig: 1.6416, Accuracy: 0.5625
# Batch no: 016, Loss on trainig: 2.0350, Accuracy: 0.4375
# Batch no: 017, Loss on trainig: 1.9309, Accuracy: 0.4531
# Batch no: 018, Loss on trainig: 1.4391, Accuracy: 0.5781
# Batch no: 019, Loss on trainig: 1.5646, Accuracy: 0.5312
# Batch no: 020, Loss on trainig: 1.6694, Accuracy: 0.5469
# Batch no: 021, Loss on trainig: 1.9302, Accuracy: 0.4219
# Batch no: 022, Loss on trainig: 1.7566, Accuracy: 0.5469
# Batch no: 023, Loss on trainig: 1.9589, Accuracy: 0.4375
# Batch no: 024, Loss on trainig: 1.7339, Accuracy: 0.4688
# Batch no: 025, Loss on trainig: 1.9459, Accuracy: 0.5156
# Batch no: 026, Loss on trainig: 1.9854, Accuracy: 0.4219
# Batch no: 027, Loss on trainig: 2.1648, Accuracy: 0.4219
# Batch no: 028, Loss on trainig: 2.0591, Accuracy: 0.4375
# Batch no: 029, Loss on trainig: 1.9546, Accuracy: 0.4844
# Batch no: 030, Loss on trainig: 1.9375, Accuracy: 0.4062
# Batch no: 031, Loss on trainig: 1.5581, Accuracy: 0.5625
# Batch no: 032, Loss on trainig: 1.9654, Accuracy: 0.4531
# Batch no: 033, Loss on trainig: 2.2104, Accuracy: 0.4688
# Batch no: 034, Loss on trainig: 2.1690, Accuracy: 0.3906
# Batch no: 035, Loss on trainig: 1.7166, Accuracy: 0.5000
# Batch no: 036, Loss on trainig: 1.4835, Accuracy: 0.5469
# Batch no: 037, Loss on trainig: 1.4805, Accuracy: 0.5312
# Batch no: 038, Loss on trainig: 1.8835, Accuracy: 0.3750
# Batch no: 039, Loss on trainig: 1.6050, Accuracy: 0.5469
# Batch no: 040, Loss on trainig: 2.0558, Accuracy: 0.4219
# Batch no: 041, Loss on trainig: 2.0605, Accuracy: 0.4219
# Batch no: 042, Loss on trainig: 1.5900, Accuracy: 0.5469
# Batch no: 043, Loss on trainig: 1.7409, Accuracy: 0.4531
# Batch no: 044, Loss on trainig: 1.6894, Accuracy: 0.5000
# Batch no: 045, Loss on trainig: 1.7141, Accuracy: 0.5156
# Batch no: 046, Loss on trainig: 1.7220, Accuracy: 0.5312
# Batch no: 047, Loss on trainig: 1.7640, Accuracy: 0.5312
# Batch no: 048, Loss on trainig: 1.6829, Accuracy: 0.5625
# Batch no: 049, Loss on trainig: 1.3424, Accuracy: 0.5938
# Batch no: 050, Loss on trainig: 2.0526, Accuracy: 0.4062
# Batch no: 051, Loss on trainig: 1.7843, Accuracy: 0.5938
# Batch no: 052, Loss on trainig: 1.6614, Accuracy: 0.4844
# Batch no: 053, Loss on trainig: 1.7532, Accuracy: 0.4844
# Batch no: 054, Loss on trainig: 1.7055, Accuracy: 0.4688
# Batch no: 055, Loss on trainig: 1.3946, Accuracy: 0.6562
# Batch no: 056, Loss on trainig: 1.7145, Accuracy: 0.5469
# Batch no: 057, Loss on trainig: 1.8650, Accuracy: 0.4844
# Batch no: 058, Loss on trainig: 1.7933, Accuracy: 0.5156
# Batch no: 059, Loss on trainig: 1.6411, Accuracy: 0.5156
# Batch no: 060, Loss on trainig: 1.7708, Accuracy: 0.5312
# Batch no: 061, Loss on trainig: 1.5917, Accuracy: 0.5625
# Batch no: 062, Loss on trainig: 1.8153, Accuracy: 0.4844
# Batch no: 063, Loss on trainig: 1.7944, Accuracy: 0.5000
# Batch no: 064, Loss on trainig: 1.5335, Accuracy: 0.5312
# Batch no: 065, Loss on trainig: 1.7870, Accuracy: 0.5312
# Batch no: 066, Loss on trainig: 1.7912, Accuracy: 0.5625
# Batch no: 067, Loss on trainig: 1.3398, Accuracy: 0.6094
# Batch no: 068, Loss on trainig: 1.6534, Accuracy: 0.5156
# Batch no: 069, Loss on trainig: 2.4441, Accuracy: 0.4219
# Batch no: 070, Loss on trainig: 1.8183, Accuracy: 0.4688
# Batch no: 071, Loss on trainig: 1.9253, Accuracy: 0.5156
# Batch no: 072, Loss on trainig: 1.6165, Accuracy: 0.5312
# Batch no: 073, Loss on trainig: 2.1572, Accuracy: 0.4062
# Batch no: 074, Loss on trainig: 1.7550, Accuracy: 0.5312
# Batch no: 075, Loss on trainig: 1.7603, Accuracy: 0.4844
# Batch no: 076, Loss on trainig: 1.6271, Accuracy: 0.5781
# Batch no: 077, Loss on trainig: 1.8454, Accuracy: 0.5312
# Batch no: 078, Loss on trainig: 1.8048, Accuracy: 0.5000
# Batch no: 079, Loss on trainig: 1.6938, Accuracy: 0.5000
# Batch no: 080, Loss on trainig: 1.4314, Accuracy: 0.5469
# Batch no: 081, Loss on trainig: 2.3789, Accuracy: 0.3438
# Batch no: 082, Loss on trainig: 1.9915, Accuracy: 0.4531
# Batch no: 083, Loss on trainig: 1.7818, Accuracy: 0.4844
# Batch no: 084, Loss on trainig: 1.6975, Accuracy: 0.5312
# Batch no: 085, Loss on trainig: 1.5936, Accuracy: 0.6250
# Batch no: 086, Loss on trainig: 1.6473, Accuracy: 0.5469
# Batch no: 087, Loss on trainig: 1.8111, Accuracy: 0.5312
# Batch no: 088, Loss on trainig: 1.5721, Accuracy: 0.5469
# Batch no: 089, Loss on trainig: 1.6095, Accuracy: 0.5781
# Batch no: 090, Loss on trainig: 1.6058, Accuracy: 0.5625
# Batch no: 091, Loss on trainig: 1.7282, Accuracy: 0.5312
# Batch no: 092, Loss on trainig: 2.1555, Accuracy: 0.4219
# Batch no: 093, Loss on trainig: 1.2965, Accuracy: 0.6875
# Batch no: 094, Loss on trainig: 1.6912, Accuracy: 0.5625
# Batch no: 095, Loss on trainig: 1.7325, Accuracy: 0.5469
# Batch no: 096, Loss on trainig: 1.9038, Accuracy: 0.5156
# Batch no: 097, Loss on trainig: 1.6543, Accuracy: 0.5469
# Batch no: 098, Loss on trainig: 1.9504, Accuracy: 0.5000
# Batch no: 099, Loss on trainig: 2.2118, Accuracy: 0.4531
# Batch no: 100, Loss on trainig: 1.7872, Accuracy: 0.4844
# Batch no: 101, Loss on trainig: 2.2226, Accuracy: 0.4219
# Batch no: 102, Loss on trainig: 1.8534, Accuracy: 0.4583
# Epoch: 7/18
# Batch no: 000, Loss on trainig: 1.8774, Accuracy: 0.5000
# Batch no: 001, Loss on trainig: 1.7972, Accuracy: 0.5156
# Batch no: 002, Loss on trainig: 1.7605, Accuracy: 0.5312
# Batch no: 003, Loss on trainig: 1.7351, Accuracy: 0.4688
# Batch no: 004, Loss on trainig: 1.9376, Accuracy: 0.5000
# Batch no: 005, Loss on trainig: 1.8876, Accuracy: 0.5156
# Batch no: 006, Loss on trainig: 1.7848, Accuracy: 0.4844
# Batch no: 007, Loss on trainig: 1.3008, Accuracy: 0.7031
# Batch no: 008, Loss on trainig: 1.5766, Accuracy: 0.5625
# Batch no: 009, Loss on trainig: 1.7318, Accuracy: 0.5469
# Batch no: 010, Loss on trainig: 1.9200, Accuracy: 0.5156
# Batch no: 011, Loss on trainig: 1.7814, Accuracy: 0.5156
# Batch no: 012, Loss on trainig: 1.4474, Accuracy: 0.5938
# Batch no: 013, Loss on trainig: 1.5465, Accuracy: 0.5938
# Batch no: 014, Loss on trainig: 1.5900, Accuracy: 0.5000
# Batch no: 015, Loss on trainig: 1.8626, Accuracy: 0.4531
# Batch no: 016, Loss on trainig: 1.9273, Accuracy: 0.5000
# Batch no: 017, Loss on trainig: 1.9572, Accuracy: 0.4531
# Batch no: 018, Loss on trainig: 1.8364, Accuracy: 0.5938
# Batch no: 019, Loss on trainig: 1.6990, Accuracy: 0.5469
# Batch no: 020, Loss on trainig: 2.2164, Accuracy: 0.4375
# Batch no: 021, Loss on trainig: 1.8049, Accuracy: 0.5312
# Batch no: 022, Loss on trainig: 1.4070, Accuracy: 0.5938
# Batch no: 023, Loss on trainig: 1.6864, Accuracy: 0.5312
# Batch no: 024, Loss on trainig: 1.7390, Accuracy: 0.5000
# Batch no: 025, Loss on trainig: 1.9605, Accuracy: 0.4844
# Batch no: 026, Loss on trainig: 1.4104, Accuracy: 0.6094
# Batch no: 027, Loss on trainig: 1.8736, Accuracy: 0.4688
# Batch no: 028, Loss on trainig: 1.9329, Accuracy: 0.4531
# Batch no: 029, Loss on trainig: 1.6401, Accuracy: 0.5469
# Batch no: 030, Loss on trainig: 1.8437, Accuracy: 0.5312
# Batch no: 031, Loss on trainig: 1.9935, Accuracy: 0.4688
# Batch no: 032, Loss on trainig: 1.8665, Accuracy: 0.4531
# Batch no: 033, Loss on trainig: 2.0294, Accuracy: 0.4219
# Batch no: 034, Loss on trainig: 1.7139, Accuracy: 0.5625
# Batch no: 035, Loss on trainig: 1.4597, Accuracy: 0.5625
# Batch no: 036, Loss on trainig: 1.9244, Accuracy: 0.4844
# Batch no: 037, Loss on trainig: 1.7234, Accuracy: 0.5000
# Batch no: 038, Loss on trainig: 1.4634, Accuracy: 0.5781
# Batch no: 039, Loss on trainig: 1.9237, Accuracy: 0.4531
# Batch no: 040, Loss on trainig: 2.1193, Accuracy: 0.4062
# Batch no: 041, Loss on trainig: 2.4092, Accuracy: 0.3906
# Batch no: 042, Loss on trainig: 1.8441, Accuracy: 0.5156
# Batch no: 043, Loss on trainig: 1.5552, Accuracy: 0.5781
# Batch no: 044, Loss on trainig: 1.9137, Accuracy: 0.4531
# Batch no: 045, Loss on trainig: 1.3793, Accuracy: 0.6094
# Batch no: 046, Loss on trainig: 1.5947, Accuracy: 0.5469
# Batch no: 047, Loss on trainig: 1.7375, Accuracy: 0.5312
# Batch no: 048, Loss on trainig: 1.5300, Accuracy: 0.5000
# Batch no: 049, Loss on trainig: 1.7414, Accuracy: 0.5625
# Batch no: 050, Loss on trainig: 1.4410, Accuracy: 0.6094
# Batch no: 051, Loss on trainig: 1.4517, Accuracy: 0.6406
# Batch no: 052, Loss on trainig: 1.3053, Accuracy: 0.7031
# Batch no: 053, Loss on trainig: 1.8132, Accuracy: 0.5312
# Batch no: 054, Loss on trainig: 1.6407, Accuracy: 0.5781
# Batch no: 055, Loss on trainig: 1.6434, Accuracy: 0.6250
# Batch no: 056, Loss on trainig: 1.6882, Accuracy: 0.5000
# Batch no: 057, Loss on trainig: 1.3745, Accuracy: 0.5781
# Batch no: 058, Loss on trainig: 2.2797, Accuracy: 0.4062
# Batch no: 059, Loss on trainig: 1.7275, Accuracy: 0.5469
# Batch no: 060, Loss on trainig: 1.8320, Accuracy: 0.5312
# Batch no: 061, Loss on trainig: 1.8525, Accuracy: 0.4531
# Batch no: 062, Loss on trainig: 1.7904, Accuracy: 0.4844
# Batch no: 063, Loss on trainig: 1.7228, Accuracy: 0.5000
# Batch no: 064, Loss on trainig: 1.7241, Accuracy: 0.5625
# Batch no: 065, Loss on trainig: 1.7652, Accuracy: 0.4844
# Batch no: 066, Loss on trainig: 1.9149, Accuracy: 0.5469
# Batch no: 067, Loss on trainig: 1.6234, Accuracy: 0.5469
# Batch no: 068, Loss on trainig: 2.4231, Accuracy: 0.3750
# Batch no: 069, Loss on trainig: 1.6265, Accuracy: 0.5781
# Batch no: 070, Loss on trainig: 1.9106, Accuracy: 0.4844
# Batch no: 071, Loss on trainig: 1.4509, Accuracy: 0.5781
# Batch no: 072, Loss on trainig: 2.3637, Accuracy: 0.3438
# Batch no: 073, Loss on trainig: 1.8662, Accuracy: 0.5469
# Batch no: 074, Loss on trainig: 1.7569, Accuracy: 0.4844
# Batch no: 075, Loss on trainig: 1.6600, Accuracy: 0.5156
# Batch no: 076, Loss on trainig: 1.6065, Accuracy: 0.5781
# Batch no: 077, Loss on trainig: 1.8369, Accuracy: 0.5000
# Batch no: 078, Loss on trainig: 1.5917, Accuracy: 0.5781
# Batch no: 079, Loss on trainig: 1.6015, Accuracy: 0.5469
# Batch no: 080, Loss on trainig: 1.8004, Accuracy: 0.4531
# Batch no: 081, Loss on trainig: 2.1923, Accuracy: 0.4531
# Batch no: 082, Loss on trainig: 2.0209, Accuracy: 0.5312
# Batch no: 083, Loss on trainig: 1.9074, Accuracy: 0.4844
# Batch no: 084, Loss on trainig: 2.0376, Accuracy: 0.4844
# Batch no: 085, Loss on trainig: 1.8113, Accuracy: 0.4844
# Batch no: 086, Loss on trainig: 1.5639, Accuracy: 0.5625
# Batch no: 087, Loss on trainig: 1.5910, Accuracy: 0.5469
# Batch no: 088, Loss on trainig: 1.8307, Accuracy: 0.4531
# Batch no: 089, Loss on trainig: 1.6890, Accuracy: 0.5938
# Batch no: 090, Loss on trainig: 1.6507, Accuracy: 0.5156
# Batch no: 091, Loss on trainig: 1.3991, Accuracy: 0.5312
# Batch no: 092, Loss on trainig: 2.2143, Accuracy: 0.4844
# Batch no: 093, Loss on trainig: 1.6615, Accuracy: 0.5156
# Batch no: 094, Loss on trainig: 1.8920, Accuracy: 0.5000
# Batch no: 095, Loss on trainig: 1.7882, Accuracy: 0.5469
# Batch no: 096, Loss on trainig: 1.7919, Accuracy: 0.5781
# Batch no: 097, Loss on trainig: 1.9009, Accuracy: 0.5625
# Batch no: 098, Loss on trainig: 1.6305, Accuracy: 0.5469
# Batch no: 099, Loss on trainig: 1.4575, Accuracy: 0.6094
# Batch no: 100, Loss on trainig: 1.9046, Accuracy: 0.4219
# Batch no: 101, Loss on trainig: 1.8345, Accuracy: 0.5312
# Batch no: 102, Loss on trainig: 1.8947, Accuracy: 0.6250
# Epoch: 8/18
# Batch no: 000, Loss on trainig: 1.5190, Accuracy: 0.5625
# Batch no: 001, Loss on trainig: 1.7982, Accuracy: 0.5312
# Batch no: 002, Loss on trainig: 1.4510, Accuracy: 0.5938
# Batch no: 003, Loss on trainig: 1.5347, Accuracy: 0.5625
# Batch no: 004, Loss on trainig: 1.5302, Accuracy: 0.5312
# Batch no: 005, Loss on trainig: 1.7534, Accuracy: 0.5312
# Batch no: 006, Loss on trainig: 1.5422, Accuracy: 0.5469
# Batch no: 007, Loss on trainig: 1.7892, Accuracy: 0.5156
# Batch no: 008, Loss on trainig: 1.5523, Accuracy: 0.5781
# Batch no: 009, Loss on trainig: 1.6643, Accuracy: 0.5938
# Batch no: 010, Loss on trainig: 1.9156, Accuracy: 0.4531
# Batch no: 011, Loss on trainig: 1.8064, Accuracy: 0.5781
# Batch no: 012, Loss on trainig: 1.4474, Accuracy: 0.6250
# Batch no: 013, Loss on trainig: 1.4267, Accuracy: 0.5781
# Batch no: 014, Loss on trainig: 1.7326, Accuracy: 0.5312
# Batch no: 015, Loss on trainig: 1.4874, Accuracy: 0.5781
# Batch no: 016, Loss on trainig: 1.6311, Accuracy: 0.5156
# Batch no: 017, Loss on trainig: 1.8784, Accuracy: 0.4531
# Batch no: 018, Loss on trainig: 2.2688, Accuracy: 0.3594
# Batch no: 019, Loss on trainig: 1.8448, Accuracy: 0.5000
# Batch no: 020, Loss on trainig: 1.4598, Accuracy: 0.6250
# Batch no: 021, Loss on trainig: 1.8622, Accuracy: 0.5781
# Batch no: 022, Loss on trainig: 1.6391, Accuracy: 0.5469
# Batch no: 023, Loss on trainig: 1.4112, Accuracy: 0.5781
# Batch no: 024, Loss on trainig: 1.6110, Accuracy: 0.5469
# Batch no: 025, Loss on trainig: 1.7460, Accuracy: 0.4844
# Batch no: 026, Loss on trainig: 1.6322, Accuracy: 0.6250
# Batch no: 027, Loss on trainig: 1.7314, Accuracy: 0.5625
# Batch no: 028, Loss on trainig: 1.4029, Accuracy: 0.6719
# Batch no: 029, Loss on trainig: 1.4034, Accuracy: 0.6250
# Batch no: 030, Loss on trainig: 1.6612, Accuracy: 0.4844
# Batch no: 031, Loss on trainig: 1.6018, Accuracy: 0.5469
# Batch no: 032, Loss on trainig: 1.6441, Accuracy: 0.5312
# Batch no: 033, Loss on trainig: 1.7415, Accuracy: 0.5156
# Batch no: 034, Loss on trainig: 1.5874, Accuracy: 0.5625
# Batch no: 035, Loss on trainig: 1.4365, Accuracy: 0.5938
# Batch no: 036, Loss on trainig: 1.8046, Accuracy: 0.5469
# Batch no: 037, Loss on trainig: 1.6940, Accuracy: 0.5469
# Batch no: 038, Loss on trainig: 1.9482, Accuracy: 0.4375
# Batch no: 039, Loss on trainig: 1.8838, Accuracy: 0.4844
# Batch no: 040, Loss on trainig: 1.9658, Accuracy: 0.5000
# Batch no: 041, Loss on trainig: 2.1975, Accuracy: 0.4062
# Batch no: 042, Loss on trainig: 1.6299, Accuracy: 0.5469
# Batch no: 043, Loss on trainig: 2.0730, Accuracy: 0.4844
# Batch no: 044, Loss on trainig: 1.7579, Accuracy: 0.5156
# Batch no: 045, Loss on trainig: 1.5760, Accuracy: 0.5312
# Batch no: 046, Loss on trainig: 1.6835, Accuracy: 0.5000
# Batch no: 047, Loss on trainig: 1.6844, Accuracy: 0.5625
# Batch no: 048, Loss on trainig: 1.7203, Accuracy: 0.5469
# Batch no: 049, Loss on trainig: 1.6384, Accuracy: 0.5000
# Batch no: 050, Loss on trainig: 1.8749, Accuracy: 0.4531
# Batch no: 051, Loss on trainig: 1.5311, Accuracy: 0.5781
# Batch no: 052, Loss on trainig: 1.7899, Accuracy: 0.5156
# Batch no: 053, Loss on trainig: 1.3895, Accuracy: 0.6562
# Batch no: 054, Loss on trainig: 1.6796, Accuracy: 0.5312
# Batch no: 055, Loss on trainig: 1.4271, Accuracy: 0.6094
# Batch no: 056, Loss on trainig: 1.6637, Accuracy: 0.5469
# Batch no: 057, Loss on trainig: 1.2941, Accuracy: 0.6250
# Batch no: 058, Loss on trainig: 1.3437, Accuracy: 0.6562
# Batch no: 059, Loss on trainig: 1.5502, Accuracy: 0.5156
# Batch no: 060, Loss on trainig: 1.7834, Accuracy: 0.4688
# Batch no: 061, Loss on trainig: 1.8650, Accuracy: 0.5312
# Batch no: 062, Loss on trainig: 1.7010, Accuracy: 0.5938
# Batch no: 063, Loss on trainig: 1.9719, Accuracy: 0.5000
# Batch no: 064, Loss on trainig: 1.6225, Accuracy: 0.5000
# Batch no: 065, Loss on trainig: 1.5126, Accuracy: 0.5938
# Batch no: 066, Loss on trainig: 1.7492, Accuracy: 0.4375
# Batch no: 067, Loss on trainig: 1.5858, Accuracy: 0.5938
# Batch no: 068, Loss on trainig: 1.8102, Accuracy: 0.5000
# Batch no: 069, Loss on trainig: 1.4287, Accuracy: 0.5625
# Batch no: 070, Loss on trainig: 1.1247, Accuracy: 0.6875
# Batch no: 071, Loss on trainig: 1.8108, Accuracy: 0.5156
# Batch no: 072, Loss on trainig: 1.5606, Accuracy: 0.5938
# Batch no: 073, Loss on trainig: 1.3827, Accuracy: 0.5781
# Batch no: 074, Loss on trainig: 1.8056, Accuracy: 0.5156
# Batch no: 075, Loss on trainig: 1.6253, Accuracy: 0.5469
# Batch no: 076, Loss on trainig: 1.6669, Accuracy: 0.5625
# Batch no: 077, Loss on trainig: 1.6004, Accuracy: 0.5938
# Batch no: 078, Loss on trainig: 1.5466, Accuracy: 0.6562
# Batch no: 079, Loss on trainig: 1.5645, Accuracy: 0.5312
# Batch no: 080, Loss on trainig: 1.9036, Accuracy: 0.4844
# Batch no: 081, Loss on trainig: 1.5020, Accuracy: 0.6094
# Batch no: 082, Loss on trainig: 1.5513, Accuracy: 0.5156
# Batch no: 083, Loss on trainig: 1.6563, Accuracy: 0.5469
# Batch no: 084, Loss on trainig: 1.8930, Accuracy: 0.4688
# Batch no: 085, Loss on trainig: 1.5064, Accuracy: 0.5625
# Batch no: 086, Loss on trainig: 1.7389, Accuracy: 0.4688
# Batch no: 087, Loss on trainig: 1.5467, Accuracy: 0.5000
# Batch no: 088, Loss on trainig: 1.4594, Accuracy: 0.6094
# Batch no: 089, Loss on trainig: 1.9805, Accuracy: 0.4844
# Batch no: 090, Loss on trainig: 1.5754, Accuracy: 0.6250
# Batch no: 091, Loss on trainig: 1.4869, Accuracy: 0.6562
# Batch no: 092, Loss on trainig: 2.0103, Accuracy: 0.4844
# Batch no: 093, Loss on trainig: 2.2162, Accuracy: 0.4531
# Batch no: 094, Loss on trainig: 1.6916, Accuracy: 0.6094
# Batch no: 095, Loss on trainig: 1.5747, Accuracy: 0.6562
# Batch no: 096, Loss on trainig: 1.8937, Accuracy: 0.4219
# Batch no: 097, Loss on trainig: 1.7370, Accuracy: 0.5156
# Batch no: 098, Loss on trainig: 1.4218, Accuracy: 0.5625
# Batch no: 099, Loss on trainig: 1.5157, Accuracy: 0.6094
# Batch no: 100, Loss on trainig: 1.6570, Accuracy: 0.5312
# Batch no: 101, Loss on trainig: 1.6619, Accuracy: 0.5625
# Batch no: 102, Loss on trainig: 1.6302, Accuracy: 0.5000
# Epoch: 9/18
# Batch no: 000, Loss on trainig: 1.7094, Accuracy: 0.5469
# Batch no: 001, Loss on trainig: 1.9621, Accuracy: 0.4688
# Batch no: 002, Loss on trainig: 2.1609, Accuracy: 0.4688
# Batch no: 003, Loss on trainig: 1.5246, Accuracy: 0.6094
# Batch no: 004, Loss on trainig: 1.4658, Accuracy: 0.5625
# Batch no: 005, Loss on trainig: 1.6456, Accuracy: 0.5156
# Batch no: 006, Loss on trainig: 1.7348, Accuracy: 0.5156
# Batch no: 007, Loss on trainig: 1.4312, Accuracy: 0.6094
# Batch no: 008, Loss on trainig: 1.7318, Accuracy: 0.5469
# Batch no: 009, Loss on trainig: 1.4748, Accuracy: 0.5312
# Batch no: 010, Loss on trainig: 1.9779, Accuracy: 0.5312
# Batch no: 011, Loss on trainig: 1.7397, Accuracy: 0.5469
# Batch no: 012, Loss on trainig: 1.7122, Accuracy: 0.4844
# Batch no: 013, Loss on trainig: 1.4183, Accuracy: 0.5781
# Batch no: 014, Loss on trainig: 1.1789, Accuracy: 0.6406
# Batch no: 015, Loss on trainig: 2.0378, Accuracy: 0.4688
# ...
# Batch no: 029, Loss on trainig: 1.2998, Accuracy: 0.6562
# Batch no: 030, Loss on trainig: 1.2976, Accuracy: 0.6094
# Batch no: 031, Loss on trainig: 1.3084, Accuracy: 0.6875
# Batch no: 032, Loss on trainig: 1.3086, Accuracy: 0.5938
# Batch no: 033, Loss on trainig: 1.3456, Accuracy: 0.5781
# Batch no: 034, Loss on trainig: 1.3296, Accuracy: 0.5938
# Batch no: 035, Loss on trainig: 1.3536, Accuracy: 0.6562
# Batch no: 036, Loss on trainig: 1.3135, Accuracy: 0.6562
# Batch no: 037, Loss on trainig: 1.4011, Accuracy: 0.5938
# Batch no: 038, Loss on trainig: 1.5852, Accuracy: 0.6250
# Batch no: 039, Loss on trainig: 1.3793, Accuracy: 0.6406
# Batch no: 040, Loss on trainig: 1.3461, Accuracy: 0.6094
# Batch no: 041, Loss on trainig: 1.5748, Accuracy: 0.5312
# Batch no: 042, Loss on trainig: 1.3185, Accuracy: 0.6562
# Batch no: 043, Loss on trainig: 1.2643, Accuracy: 0.5781
# Batch no: 044, Loss on trainig: 1.2987, Accuracy: 0.5938
# Batch no: 045, Loss on trainig: 1.4306, Accuracy: 0.5781
# Batch no: 046, Loss on trainig: 1.5216, Accuracy: 0.6250
# Batch no: 047, Loss on trainig: 1.4524, Accuracy: 0.5938
# Batch no: 048, Loss on trainig: 1.7048, Accuracy: 0.5000
# Batch no: 049, Loss on trainig: 1.2485, Accuracy: 0.6719
# Batch no: 050, Loss on trainig: 1.4374, Accuracy: 0.5938
# Batch no: 051, Loss on trainig: 1.5126, Accuracy: 0.5938
# Batch no: 052, Loss on trainig: 1.3496, Accuracy: 0.6406
# Batch no: 053, Loss on trainig: 1.2113, Accuracy: 0.6094
# Batch no: 054, Loss on trainig: 1.0242, Accuracy: 0.7031
# Batch no: 055, Loss on trainig: 1.4567, Accuracy: 0.6562
# Batch no: 056, Loss on trainig: 1.1511, Accuracy: 0.6406
# Batch no: 057, Loss on trainig: 1.6979, Accuracy: 0.5625
# Batch no: 058, Loss on trainig: 1.5355, Accuracy: 0.5781
# Batch no: 059, Loss on trainig: 1.2350, Accuracy: 0.5938
# Batch no: 060, Loss on trainig: 1.5330, Accuracy: 0.5312
# Batch no: 061, Loss on trainig: 1.2940, Accuracy: 0.6719
# Batch no: 062, Loss on trainig: 1.2466, Accuracy: 0.5625
# Batch no: 063, Loss on trainig: 1.2186, Accuracy: 0.6719
# Batch no: 064, Loss on trainig: 1.0961, Accuracy: 0.7500
# Batch no: 065, Loss on trainig: 1.4979, Accuracy: 0.5938
# Batch no: 066, Loss on trainig: 1.3490, Accuracy: 0.5938
# Batch no: 067, Loss on trainig: 1.3028, Accuracy: 0.6406
# Batch no: 068, Loss on trainig: 1.6003, Accuracy: 0.5469
# Batch no: 069, Loss on trainig: 1.1997, Accuracy: 0.6562
# Batch no: 070, Loss on trainig: 1.5315, Accuracy: 0.5156
# Batch no: 071, Loss on trainig: 1.5085, Accuracy: 0.6094
# Batch no: 072, Loss on trainig: 1.3558, Accuracy: 0.6094
# Batch no: 073, Loss on trainig: 1.3325, Accuracy: 0.6406
# Batch no: 074, Loss on trainig: 1.4699, Accuracy: 0.6719
# Batch no: 075, Loss on trainig: 1.2319, Accuracy: 0.6562
# Batch no: 076, Loss on trainig: 1.3581, Accuracy: 0.6250
# Batch no: 077, Loss on trainig: 1.6478, Accuracy: 0.5469
# Batch no: 078, Loss on trainig: 1.4628, Accuracy: 0.6250
# Batch no: 079, Loss on trainig: 1.6617, Accuracy: 0.5156
# Batch no: 080, Loss on trainig: 1.7130, Accuracy: 0.5469
# Batch no: 081, Loss on trainig: 1.4030, Accuracy: 0.6250
# Batch no: 082, Loss on trainig: 1.9179, Accuracy: 0.5156
# Batch no: 083, Loss on trainig: 1.1390, Accuracy: 0.6719
# Batch no: 084, Loss on trainig: 1.3061, Accuracy: 0.6562
# Batch no: 085, Loss on trainig: 1.4103, Accuracy: 0.6094
# Batch no: 086, Loss on trainig: 1.6824, Accuracy: 0.5469
# Batch no: 087, Loss on trainig: 1.4582, Accuracy: 0.6094
# Batch no: 088, Loss on trainig: 1.2800, Accuracy: 0.6406
# Batch no: 089, Loss on trainig: 1.4723, Accuracy: 0.5938
# Batch no: 090, Loss on trainig: 1.5093, Accuracy: 0.5938
# Batch no: 091, Loss on trainig: 1.4137, Accuracy: 0.6406
# Batch no: 092, Loss on trainig: 1.4683, Accuracy: 0.6406
# Batch no: 093, Loss on trainig: 1.6183, Accuracy: 0.5000
# Batch no: 094, Loss on trainig: 1.2507, Accuracy: 0.6406
# Batch no: 095, Loss on trainig: 1.2231, Accuracy: 0.6562
# Batch no: 096, Loss on trainig: 1.4718, Accuracy: 0.6094
# Batch no: 097, Loss on trainig: 1.4150, Accuracy: 0.5781
# Batch no: 098, Loss on trainig: 1.1865, Accuracy: 0.6250
# Batch no: 099, Loss on trainig: 1.6095, Accuracy: 0.6250
# Batch no: 100, Loss on trainig: 1.1991, Accuracy: 0.6406
# Batch no: 101, Loss on trainig: 1.2940, Accuracy: 0.6406
# Batch no: 102, Loss on trainig: 1.5111, Accuracy: 0.6250
# Epoch: 17/18
# Batch no: 000, Loss on trainig: 1.5251, Accuracy: 0.6094
# Batch no: 001, Loss on trainig: 1.4304, Accuracy: 0.5469
# Batch no: 002, Loss on trainig: 1.5180, Accuracy: 0.5938
# Batch no: 003, Loss on trainig: 1.4970, Accuracy: 0.5938
# Batch no: 004, Loss on trainig: 1.2424, Accuracy: 0.6875
# Batch no: 005, Loss on trainig: 1.1641, Accuracy: 0.6562
# Batch no: 006, Loss on trainig: 1.3371, Accuracy: 0.6094
# Batch no: 007, Loss on trainig: 1.6424, Accuracy: 0.6094
# Batch no: 008, Loss on trainig: 1.2082, Accuracy: 0.6875
# Batch no: 009, Loss on trainig: 0.9671, Accuracy: 0.7188
# Batch no: 010, Loss on trainig: 1.5524, Accuracy: 0.5625
# Batch no: 011, Loss on trainig: 1.0913, Accuracy: 0.7344
# Batch no: 012, Loss on trainig: 1.3541, Accuracy: 0.6094
# Batch no: 013, Loss on trainig: 1.4081, Accuracy: 0.5938
# Batch no: 014, Loss on trainig: 1.4190, Accuracy: 0.6562
# Batch no: 015, Loss on trainig: 1.2906, Accuracy: 0.6562
# Batch no: 016, Loss on trainig: 1.2613, Accuracy: 0.6719
# Batch no: 017, Loss on trainig: 1.2538, Accuracy: 0.6094
# Batch no: 018, Loss on trainig: 1.5617, Accuracy: 0.6094
# Batch no: 019, Loss on trainig: 1.2617, Accuracy: 0.6406
# Batch no: 020, Loss on trainig: 1.1593, Accuracy: 0.6562
# Batch no: 021, Loss on trainig: 1.4443, Accuracy: 0.6094
# Batch no: 022, Loss on trainig: 1.2536, Accuracy: 0.6094
# Batch no: 023, Loss on trainig: 1.2277, Accuracy: 0.6719
# Batch no: 024, Loss on trainig: 1.4917, Accuracy: 0.5469
# Batch no: 025, Loss on trainig: 0.9960, Accuracy: 0.7344
# Batch no: 026, Loss on trainig: 1.3734, Accuracy: 0.6250
# Batch no: 027, Loss on trainig: 1.1890, Accuracy: 0.6875
# Batch no: 028, Loss on trainig: 1.5459, Accuracy: 0.5938
# Batch no: 029, Loss on trainig: 1.4355, Accuracy: 0.6250
# Batch no: 030, Loss on trainig: 1.4933, Accuracy: 0.5469
# Batch no: 031, Loss on trainig: 1.2184, Accuracy: 0.6406
# Batch no: 032, Loss on trainig: 1.3948, Accuracy: 0.6406
# Batch no: 033, Loss on trainig: 1.5907, Accuracy: 0.5938
# Batch no: 034, Loss on trainig: 1.2520, Accuracy: 0.6250
# Batch no: 035, Loss on trainig: 1.2436, Accuracy: 0.6562
# Batch no: 036, Loss on trainig: 1.2852, Accuracy: 0.5469
# Batch no: 037, Loss on trainig: 1.4009, Accuracy: 0.6094
# Batch no: 038, Loss on trainig: 1.3227, Accuracy: 0.6250
# Batch no: 039, Loss on trainig: 1.4241, Accuracy: 0.5781
# Batch no: 040, Loss on trainig: 1.2891, Accuracy: 0.6406
# Batch no: 041, Loss on trainig: 1.2970, Accuracy: 0.6719
# Batch no: 042, Loss on trainig: 0.9387, Accuracy: 0.7344
# Batch no: 043, Loss on trainig: 1.2023, Accuracy: 0.6719
# Batch no: 044, Loss on trainig: 1.3474, Accuracy: 0.7188
# Batch no: 045, Loss on trainig: 1.4066, Accuracy: 0.6094
# Batch no: 046, Loss on trainig: 1.0342, Accuracy: 0.7188
# Batch no: 047, Loss on trainig: 1.3117, Accuracy: 0.5781
# Batch no: 048, Loss on trainig: 1.1753, Accuracy: 0.6719
# Batch no: 049, Loss on trainig: 1.5301, Accuracy: 0.6562
# Batch no: 050, Loss on trainig: 1.2916, Accuracy: 0.6094
# Batch no: 051, Loss on trainig: 1.4721, Accuracy: 0.6094
# Batch no: 052, Loss on trainig: 1.4283, Accuracy: 0.5938
# Batch no: 053, Loss on trainig: 1.0714, Accuracy: 0.6562
# Batch no: 054, Loss on trainig: 1.5645, Accuracy: 0.5781
# Batch no: 055, Loss on trainig: 1.7390, Accuracy: 0.5625
# Batch no: 056, Loss on trainig: 1.6098, Accuracy: 0.5312
# Batch no: 057, Loss on trainig: 1.6097, Accuracy: 0.5781
# Batch no: 058, Loss on trainig: 1.5130, Accuracy: 0.5625
# Batch no: 059, Loss on trainig: 1.5624, Accuracy: 0.6094
# Batch no: 060, Loss on trainig: 1.1564, Accuracy: 0.6250
# Batch no: 061, Loss on trainig: 1.4629, Accuracy: 0.6094
# Batch no: 062, Loss on trainig: 1.1654, Accuracy: 0.6875
# Batch no: 063, Loss on trainig: 1.4623, Accuracy: 0.5781
# Batch no: 064, Loss on trainig: 1.6228, Accuracy: 0.5781
# Batch no: 065, Loss on trainig: 1.0905, Accuracy: 0.6562
# Batch no: 066, Loss on trainig: 0.9782, Accuracy: 0.6250
# Batch no: 067, Loss on trainig: 1.4277, Accuracy: 0.6250
# Batch no: 068, Loss on trainig: 1.5618, Accuracy: 0.5156
# Batch no: 069, Loss on trainig: 1.6204, Accuracy: 0.5000
# Batch no: 070, Loss on trainig: 1.1032, Accuracy: 0.7188
# Batch no: 071, Loss on trainig: 1.3133, Accuracy: 0.5781
# Batch no: 072, Loss on trainig: 1.7362, Accuracy: 0.5156
# Batch no: 073, Loss on trainig: 1.4077, Accuracy: 0.6562
# Batch no: 074, Loss on trainig: 1.1309, Accuracy: 0.6719
# Batch no: 075, Loss on trainig: 1.1570, Accuracy: 0.6250
# Batch no: 076, Loss on trainig: 1.0596, Accuracy: 0.6875
# Batch no: 077, Loss on trainig: 1.5940, Accuracy: 0.5938
# Batch no: 078, Loss on trainig: 1.2545, Accuracy: 0.6875
# Batch no: 079, Loss on trainig: 1.2556, Accuracy: 0.5781
# Batch no: 080, Loss on trainig: 1.4201, Accuracy: 0.6406
# Batch no: 081, Loss on trainig: 1.5031, Accuracy: 0.5312
# Batch no: 082, Loss on trainig: 1.0720, Accuracy: 0.7500
# Batch no: 083, Loss on trainig: 1.4952, Accuracy: 0.5781
# Batch no: 084, Loss on trainig: 1.1571, Accuracy: 0.7031
# Batch no: 085, Loss on trainig: 1.4428, Accuracy: 0.5938
# Batch no: 086, Loss on trainig: 1.4808, Accuracy: 0.6562
# Batch no: 087, Loss on trainig: 1.3337, Accuracy: 0.6406
# Batch no: 088, Loss on trainig: 1.1648, Accuracy: 0.6562
# Batch no: 089, Loss on trainig: 1.2946, Accuracy: 0.6094
# Batch no: 090, Loss on trainig: 1.2876, Accuracy: 0.6562
# Batch no: 091, Loss on trainig: 1.2631, Accuracy: 0.6406
# Batch no: 092, Loss on trainig: 1.6454, Accuracy: 0.5781
# Batch no: 093, Loss on trainig: 1.4412, Accuracy: 0.5938
# Batch no: 094, Loss on trainig: 1.2142, Accuracy: 0.6875
# Batch no: 095, Loss on trainig: 1.1018, Accuracy: 0.7031
# Batch no: 096, Loss on trainig: 1.1335, Accuracy: 0.6562
# Batch no: 097, Loss on trainig: 1.5134, Accuracy: 0.5781
# Batch no: 098, Loss on trainig: 1.8058, Accuracy: 0.4375
# Batch no: 099, Loss on trainig: 1.6018, Accuracy: 0.5469
# Batch no: 100, Loss on trainig: 1.3403, Accuracy: 0.5625
# Batch no: 101, Loss on trainig: 1.3607, Accuracy: 0.6406
# Batch no: 102, Loss on trainig: 1.3947, Accuracy: 0.7083
# Epoch: 18/18
# Batch no: 000, Loss on trainig: 1.0923, Accuracy: 0.6562
# Batch no: 001, Loss on trainig: 1.6490, Accuracy: 0.5469
# Batch no: 002, Loss on trainig: 1.4241, Accuracy: 0.6250
# Batch no: 003, Loss on trainig: 1.1773, Accuracy: 0.6719
# Batch no: 004, Loss on trainig: 1.4415, Accuracy: 0.5312
# Batch no: 005, Loss on trainig: 1.3506, Accuracy: 0.6250
# Batch no: 006, Loss on trainig: 1.1555, Accuracy: 0.6875
# Batch no: 007, Loss on trainig: 1.2412, Accuracy: 0.5938
# Batch no: 008, Loss on trainig: 1.2612, Accuracy: 0.5938
# Batch no: 009, Loss on trainig: 1.4981, Accuracy: 0.5156
# Batch no: 010, Loss on trainig: 1.2950, Accuracy: 0.6250
# Batch no: 011, Loss on trainig: 0.9863, Accuracy: 0.7656
# Batch no: 012, Loss on trainig: 1.2866, Accuracy: 0.6250
# Batch no: 013, Loss on trainig: 1.2839, Accuracy: 0.6406
# Batch no: 014, Loss on trainig: 1.2760, Accuracy: 0.6719
# Batch no: 015, Loss on trainig: 1.5715, Accuracy: 0.5938
# Batch no: 016, Loss on trainig: 1.2984, Accuracy: 0.6250
# Batch no: 017, Loss on trainig: 1.2740, Accuracy: 0.5781
# Batch no: 018, Loss on trainig: 1.0013, Accuracy: 0.7188
# Batch no: 019, Loss on trainig: 1.0474, Accuracy: 0.6875
# Batch no: 020, Loss on trainig: 1.1840, Accuracy: 0.5938
# Batch no: 021, Loss on trainig: 1.2675, Accuracy: 0.7344
# Batch no: 022, Loss on trainig: 1.6070, Accuracy: 0.5625
# Batch no: 023, Loss on trainig: 1.0869, Accuracy: 0.6719
# Batch no: 024, Loss on trainig: 1.4741, Accuracy: 0.5781
# Batch no: 025, Loss on trainig: 1.4764, Accuracy: 0.5469
# Batch no: 026, Loss on trainig: 1.2392, Accuracy: 0.5938
# Batch no: 027, Loss on trainig: 1.3075, Accuracy: 0.6250
# Batch no: 028, Loss on trainig: 1.2942, Accuracy: 0.6562
# Batch no: 029, Loss on trainig: 1.2959, Accuracy: 0.5781
# Batch no: 030, Loss on trainig: 0.8964, Accuracy: 0.7500
# Batch no: 031, Loss on trainig: 1.1407, Accuracy: 0.6562
# Batch no: 032, Loss on trainig: 1.3883, Accuracy: 0.6562
# Batch no: 033, Loss on trainig: 1.6144, Accuracy: 0.5469
# Batch no: 034, Loss on trainig: 1.1351, Accuracy: 0.6094
# Batch no: 035, Loss on trainig: 1.2335, Accuracy: 0.6562
# Batch no: 036, Loss on trainig: 1.3726, Accuracy: 0.5625
# Batch no: 037, Loss on trainig: 1.5022, Accuracy: 0.5938
# Batch no: 038, Loss on trainig: 1.7969, Accuracy: 0.5000
# Batch no: 039, Loss on trainig: 1.1703, Accuracy: 0.6094
# Batch no: 040, Loss on trainig: 1.2686, Accuracy: 0.6094
# Batch no: 041, Loss on trainig: 1.2227, Accuracy: 0.6406
# Batch no: 042, Loss on trainig: 1.6801, Accuracy: 0.5625
# Batch no: 043, Loss on trainig: 1.5822, Accuracy: 0.5312
# Batch no: 044, Loss on trainig: 1.1000, Accuracy: 0.6250
# Batch no: 045, Loss on trainig: 1.6678, Accuracy: 0.5312
# Batch no: 046, Loss on trainig: 1.3630, Accuracy: 0.5938
# Batch no: 047, Loss on trainig: 1.5547, Accuracy: 0.5625
# Batch no: 048, Loss on trainig: 1.4328, Accuracy: 0.5625
# Batch no: 049, Loss on trainig: 1.6512, Accuracy: 0.5938
# Batch no: 050, Loss on trainig: 1.6033, Accuracy: 0.5781
# Batch no: 051, Loss on trainig: 1.4047, Accuracy: 0.5938
# Batch no: 052, Loss on trainig: 1.1926, Accuracy: 0.6406
# Batch no: 053, Loss on trainig: 0.9439, Accuracy: 0.7500
# Batch no: 054, Loss on trainig: 1.4438, Accuracy: 0.5312
# Batch no: 055, Loss on trainig: 1.2426, Accuracy: 0.5781
# Batch no: 056, Loss on trainig: 1.5596, Accuracy: 0.6094
# Batch no: 057, Loss on trainig: 1.0596, Accuracy: 0.7656
# Batch no: 058, Loss on trainig: 1.3940, Accuracy: 0.6094
# Batch no: 059, Loss on trainig: 1.4264, Accuracy: 0.6094
# Batch no: 060, Loss on trainig: 1.2248, Accuracy: 0.6562
# Batch no: 061, Loss on trainig: 1.5310, Accuracy: 0.6250
# Batch no: 062, Loss on trainig: 1.8384, Accuracy: 0.6250
# Batch no: 063, Loss on trainig: 1.3604, Accuracy: 0.6094
# Batch no: 064, Loss on trainig: 1.2971, Accuracy: 0.6250
# Batch no: 065, Loss on trainig: 1.4576, Accuracy: 0.4844
# Batch no: 066, Loss on trainig: 1.4333, Accuracy: 0.6719
# Batch no: 067, Loss on trainig: 1.6611, Accuracy: 0.6094
# Batch no: 068, Loss on trainig: 1.1596, Accuracy: 0.6562
# Batch no: 069, Loss on trainig: 1.1440, Accuracy: 0.6875
# Batch no: 070, Loss on trainig: 1.1390, Accuracy: 0.7188
# Batch no: 071, Loss on trainig: 1.8144, Accuracy: 0.6250
# Batch no: 072, Loss on trainig: 1.3478, Accuracy: 0.6406
# Batch no: 073, Loss on trainig: 1.6647, Accuracy: 0.5312
# Batch no: 074, Loss on trainig: 1.3712, Accuracy: 0.5781
# Batch no: 075, Loss on trainig: 1.1723, Accuracy: 0.6562
# Batch no: 076, Loss on trainig: 1.3130, Accuracy: 0.6562
# Batch no: 077, Loss on trainig: 1.4087, Accuracy: 0.6406
# Batch no: 078, Loss on trainig: 1.1606, Accuracy: 0.6719
# Batch no: 079, Loss on trainig: 1.1141, Accuracy: 0.6406
# Batch no: 080, Loss on trainig: 1.0622, Accuracy: 0.6875
# Batch no: 081, Loss on trainig: 1.5498, Accuracy: 0.6406
# Batch no: 082, Loss on trainig: 1.2965, Accuracy: 0.6094
# Batch no: 083, Loss on trainig: 1.3032, Accuracy: 0.6406
# Batch no: 084, Loss on trainig: 1.1807, Accuracy: 0.6406
# Batch no: 085, Loss on trainig: 1.1039, Accuracy: 0.7344
# Batch no: 086, Loss on trainig: 1.1153, Accuracy: 0.6719
# Batch no: 087, Loss on trainig: 1.4607, Accuracy: 0.5938
# Batch no: 088, Loss on trainig: 1.4727, Accuracy: 0.6094
# Batch no: 089, Loss on trainig: 1.0513, Accuracy: 0.7031
# Batch no: 090, Loss on trainig: 1.7570, Accuracy: 0.5781
# Batch no: 091, Loss on trainig: 1.4368, Accuracy: 0.6094
# Batch no: 092, Loss on trainig: 2.0018, Accuracy: 0.4688
# Batch no: 093, Loss on trainig: 1.2793, Accuracy: 0.6250
# Batch no: 094, Loss on trainig: 1.3555, Accuracy: 0.6250
# Batch no: 095, Loss on trainig: 1.2166, Accuracy: 0.6562
# Batch no: 096, Loss on trainig: 0.9996, Accuracy: 0.7656
# Batch no: 097, Loss on trainig: 1.2404, Accuracy: 0.6094
# Batch no: 098, Loss on trainig: 1.4630, Accuracy: 0.5469
# Batch no: 099, Loss on trainig: 1.3072, Accuracy: 0.7031
# Batch no: 100, Loss on trainig: 1.2297, Accuracy: 0.6094
# Batch no: 101, Loss on trainig: 1.3186, Accuracy: 0.6562
# Batch no: 102, Loss on trainig: 1.1077, Accuracy: 0.6667

# %%
# TODO: Do validation on the test set


# Validation - No gradient tracking needed
with torch.no_grad():
 
    # Set to evaluation mode
    model.eval()


    # Validation loop
    for j, (inputs, labels) in enumerate(validation_loader):
        inputs = inputs.to('cuda')
        labels = labels.to('cuda')
 
        # Forward pass - compute outputs on input data using the model
        outputs = model(inputs)
 
        # Compute loss
        loss = criterion(outputs, labels)
 
        # Compute the total loss for the batch and add it to valid_loss
        valid_loss += loss.item() * inputs.size(0)
 
        # Calculate validation accuracy
        ret, predictions = torch.max(outputs.data, 1)
        correct_counts = predictions.eq(labels.data.view_as(predictions))
 
        # Convert correct_counts to float and then compute the mean
        acc = torch.mean(correct_counts.type(torch.FloatTensor))
 
        # Compute total accuracy in the whole batch and add to valid_acc
        valid_acc += acc.item() * inputs.size(0)
 
        print("Validation Batch number: {:03d}, Validation: Loss: {:.4f}, Accuracy: {:.4f}".format(j, loss.item(), acc.item()))
# Out:
# Validation Batch number: 000, Validation: Loss: 0.5158, Accuracy: 0.8281
# Validation Batch number: 001, Validation: Loss: 0.4730, Accuracy: 0.8906
# Validation Batch number: 002, Validation: Loss: 0.6645, Accuracy: 0.8750
# Validation Batch number: 003, Validation: Loss: 0.5514, Accuracy: 0.8281
# Validation Batch number: 004, Validation: Loss: 0.5601, Accuracy: 0.8594
# Validation Batch number: 005, Validation: Loss: 0.5466, Accuracy: 0.8750
# Validation Batch number: 006, Validation: Loss: 0.4748, Accuracy: 0.8438
# Validation Batch number: 007, Validation: Loss: 0.7654, Accuracy: 0.9062
# Validation Batch number: 008, Validation: Loss: 0.6173, Accuracy: 0.8281
# Validation Batch number: 009, Validation: Loss: 0.5271, Accuracy: 0.8438
# Validation Batch number: 010, Validation: Loss: 0.7498, Accuracy: 0.7188
# Validation Batch number: 011, Validation: Loss: 0.4168, Accuracy: 0.8906
# Validation Batch number: 012, Validation: Loss: 0.4894, Accuracy: 0.8400

# %% [markdown]
# ## Testing your network
#
# It's good practice to test your trained network on test data, images the network has never seen either in training or validation. This will give you a good estimate for the model's performance on completely new images. Run the test images through the network and measure the accuracy, the same way you did validation. You should be able to reach around 70% accuracy on the test set if the model has been trained well.

# %%
# Do validation on the test set
correct,total = 0,0
with torch.no_grad():
    model.eval()
    for data in train_loader:
        images, labels = data
        images, labels = images.to('cuda'), labels.to('cuda')
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print('Accuracy on test images is: %d%%' % (100 * correct / total))
# Out:
# Accuracy on test images is: 82%

# %% [markdown]
# ## Save the checkpoint
#
# Now that your network is trained, save the model so you can load it later for making predictions. You probably want to save other things such as the mapping of classes to indices which you get from one of the image datasets: `image_datasets['train'].class_to_idx`. You can attach this to the model as an attribute which makes inference easier later on.
#
# ```model.class_to_idx = image_datasets['train'].class_to_idx```
#
# Remember that you'll want to completely rebuild the model later so you can use it for inference. Make sure to include any information you need in the checkpoint. If you want to load the model and keep training, you'll want to save the number of epochs as well as the optimizer state, `optimizer.state_dict`. You'll likely want to use this trained model in the next part of the project, so best to save it now.

# %%
# TODO: Save the checkpoint 


model.class_to_idx = image_datasets['train'].class_to_idx
torch.save({'structure' :'alexnet',
            'hidden_layer1':120,
             'droupout':0.5,
             'epochs':12,
             'state_dict':model.state_dict(),
             'class_to_idx':model.class_to_idx,
             'optimizer_dict':optimizer.state_dict()},
             'checkpoint.pth')

# %% [markdown]
# ## Loading the checkpoint
#
# At this point it's good to write a function that can load a checkpoint and rebuild the model. That way you can come back to this project and keep working on it without having to retrain the network.

# %%
# TODO: Write a function that loads a checkpoint and rebuilds the model

def loading_the_checkpoint(path='checkpoint.pth'):
    #load the saved file
    checkpoint = torch.load('checkpoint.pth')
    #download pretrained model
    model=models.vgg16(pretrained=True)
    #to freeze parameters
    for param in model.parameters():
        param.requires_grad = False
    #load from checkpoint
    model.class_to_idx = checkpoint['class_to_idx']
    model.load_state_dict(checkpoint['state_dict'])
    return model

# %% [markdown]
# # Inference for classification
#
# Now you'll write a function to use a trained network for inference. That is, you'll pass an image into the network and predict the class of the flower in the image. Write a function called `predict` that takes an image and a model, then returns the top $K$ most likely classes along with the probabilities. It should look like
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# First you'll need to handle processing the input image such that it can be used in your network.
#
# ## Image Preprocessing
#
# You'll want to use `PIL` to load the image ([documentation](https://pillow.readthedocs.io/en/latest/reference/Image.html)). It's best to write a function that preprocesses the image so it can be used as input for the model. This function should process the images in the same manner used for training.
#
# First, resize the images where the shortest side is 256 pixels, keeping the aspect ratio. This can be done with the [`thumbnail`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) or [`resize`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) methods. Then you'll need to crop out the center 224x224 portion of the image.
#
# Color channels of images are typically encoded as integers 0-255, but the model expected floats 0-1. You'll need to convert the values. It's easiest with a Numpy array, which you can get from a PIL image like so `np_image = np.array(pil_image)`.
#
# As before, the network expects the images to be normalized in a specific way. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`. You'll want to subtract the means from each color channel, then divide by the standard deviation.
#
# And finally, PyTorch expects the color channel to be the first dimension but it's the third dimension in the PIL image and Numpy array. You can reorder dimensions using [`ndarray.transpose`](https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.ndarray.transpose.html). The color channel needs to be first and retain the order of the other two dimensions.

# %%
# TODO: Process a PIL image for use in a PyTorch model

def process_image(image):
    ''' Scales, crops, and normalizes a PIL image for a PyTorch model,
        returns an Numpy array
    '''

    img = PIL.Image.open(image)

    # Get original dimensions
    original_width, original_height = img.size

    # Find shorter size and create settings to crop shortest side to 256
    if original_width < original_height:
        size=[256, 256**600]
    else: 
        size=[256**600, 256]
        
    img.thumbnail(size)
   

    center = original_width/4, original_height/4
    left, top, right, bottom = center[0]-(244/2), center[1]-(244/2), center[0]+(244/2), center[1]+(244/2)
    img = img.crop((left, top, right, bottom))

    numpy_img = np.array(img)/255 

    # Normalize each color channel
    mean = [0.485, 0.456, 0.406]
    std = [0.229, 0.224, 0.225]
    numpy_img = (numpy_img-mean)/std
        
    # Set the color to the first channel
    numpy_img = numpy_img.transpose(2, 0, 1)
    
    return numpy_img

# %% [markdown]
# To check your work, the function below converts a PyTorch tensor and displays it in the notebook. If your `process_image` function works, running the output through this function should return the original image (except for the cropped out portions).

# %%
def imshow(image, ax=None, title=None):
    #img for tensor
    if ax is None:
        fig, ax = plt.subplots()
    
    # PyTorch tensors assume the color channel is the first dimension
    # but matplotlib assumes is the third dimension
    image = image.transpose((1, 2, 0))   
    # Undo preprocessing
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean
    
    # Image needs to be clipped between 0 and 1 or it looks like noise when displayed
    image = np.clip(image, 0, 1)
    
    ax.imshow(image)
    
    return ax

imshow(process_image("flowers/test/9/image_06413.jpg"))
imshow(process_image("flowers/test/37/image_03734.jpg"))
imshow(process_image("flowers/test/10/image_07090.jpg"))
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Cell In[13], line 23
#      21 imshow(process_image("flowers/test/9/image_06413.jpg"))
#      22 imshow(process_image("flowers/test/37/image_03734.jpg"))
# ---> 23 imshow(process_image("flowers/test/10/image_07090.jpg"))
#
# Cell In[12], line 23, in process_image(image)
#      20 else:
#      21     size=[256**600, 256]
# ---> 23 img.thumbnail(size)
#      26 center = original_width/4, original_height/4
#      27 left, top, right, bottom = center[0]-(244/2), center[1]-(244/2), center[0]+(244/2), center[1]+(244/2)
#
# File c:\Users\arian\AppData\Local\Programs\Python\Python312\Lib\site-packages\PIL\Image.py:2609, in Image.thumbnail(self, size, resample, reducing_gap)
#    2607 box = None
#    2608 if reducing_gap is not None:
# -> 2609     size = preserve_aspect_ratio()
#    2610     if size is None:
#    2611         return
#
# File c:\Users\arian\AppData\Local\Programs\Python\Python312\Lib\site-packages\PIL\Image.py:2599, in Image.thumbnail.<locals>.preserve_aspect_ratio()
#    2596     return
#    2598 aspect = self.width / self.height
# -> 2599 if x / y >= aspect:
#    2600     x = round_aspect(y * aspect, key=lambda n: abs(aspect - n / y))
#    2601 else:
#
# OverflowError: integer division result too large for a float

# %% [markdown]
# ## Class Prediction
#
# Once you can get images in the correct format, it's time to write a function for making predictions with your model. A common practice is to predict the top 5 or so (usually called top-$K$) most probable classes. You'll want to calculate the class probabilities then find the $K$ largest values.
#
# To get the top $K$ largest values in a tensor use [`x.topk(k)`](http://pytorch.org/docs/master/torch.html#torch.topk). This method returns both the highest `k` probabilities and the indices of those probabilities corresponding to the classes. You need to convert from these indices to the actual class labels using `class_to_idx` which hopefully you added to the model or from an `ImageFolder` you used to load the data ([see here](#Save-the-checkpoint)). Make sure to invert the dictionary so you get a mapping from index to class as well.
#
# Again, this method should take a path to an image and a model checkpoint, then return the probabilities and classes.
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```

# %%
def predict(image_path, model, top_k=5):
    ''' Predict the class (or classes) of an image using a trained deep learning model.
    
    image_path: string. Path to image, directly to image and not to folder.
    model: pytorch neural network.
    top_k: integer. The top K classes to be calculated
    
    returns top_probabilities(k), top_labels
    '''
    
    # No need for GPU on this part (just causes problems)
    model.to("cpu")
    
    # Set model to evaluate
    model.eval();

    # Convert image from numpy to torch
    torch_image = torch.from_numpy(np.expand_dims(process_image(image_path), 
                                                  axis=0)).type(torch.FloatTensor).to("cpu")

    # Find probabilities (results) by passing through the function (note the log softmax means that its on a log scale)
    log_probs = model.forward(torch_image)

    # Convert to linear scale
    linear_probs = torch.exp(log_probs)

    # Find the top 5 results
    top_probs, top_labels = linear_probs.topk(top_k)
    
    # Detatch all of the details
    top_probs = np.array(top_probs.detach())[0] # This is not the correct way to do it but the correct way isnt working thanks to cpu/gpu issues so I don't care.
    top_labels = np.array(top_labels.detach())[0]
    
    # Convert to classes
    idx_to_class = {val: key for key, val in    
                                      model.class_to_idx.items()}
    top_labels = [idx_to_class[lab] for lab in top_labels]
    top_flowers = [cat_to_name[lab] for lab in top_labels]
    
    return top_probs, top_labels, top_flowers

# %% [markdown]
# ## Sanity Checking
#
# Now that you can use a trained model for predictions, check to make sure it makes sense. Even if the testing accuracy is high, it's always good to check that there aren't obvious bugs. Use `matplotlib` to plot the probabilities for the top 5 classes as a bar graph, along with the input image. It should look like this:
#
# <img src='assets/inference_example.png' width=300px>
#
# You can convert from the class integer encoding to actual flower names with the `cat_to_name.json` file (should have been loaded earlier in the notebook). To show a PyTorch tensor as an image, use the `imshow` function defined above.

# %%
# TODO: Display an image along with the top 5 classes
# Define image path
image_path = "flowers/test/37/image_03734.jpg"

# Set up plot
plt.figure(figsize = (6,10))
ax = plt.subplot(2,1,1)

# Set up title
flower_num = image_path.split('/')[2]
title_ = cat_to_name[flower_num]

# Plot flower
img = process_image(image_path)
imshow(img, ax, title = title_);

# Make prediction
probs, labs, flowers = predict(image_path, model) 

# Plot bar chart
plt.subplot(2,1,2)
sns.barplot(x=probs, y=flowers, color=sns.color_palette()[0]);
plt.show()

# %%
image_path = "flowers/test/9/image_06413.jpg"
plt.figure(figsize = (6,10))
ax = plt.subplot(2,1,1)
flower_num = image_path.split('/')[2]
title_ = cat_to_name[flower_num]
img = process_image(image_path)
imshow(img, ax, title = title_);
probs, labs, flowers = predict(image_path, model) 
plt.subplot(2,1,2)
sns.barplot(x=probs, y=flowers, color=sns.color_palette()[0]);
plt.show()
